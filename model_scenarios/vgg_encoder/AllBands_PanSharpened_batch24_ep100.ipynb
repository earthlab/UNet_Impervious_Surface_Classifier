# %%
from glob import glob

# %matplotlib inline
from pylab import *
# import cv2
import rasterio as rio

rcParams['figure.figsize'] = 10, 10

font = {'family' : 'normal',
        'weight' : 'medium',
        'size'   : 14}

matplotlib.rc('font', **font)

import os,sys
from matplotlib import pyplot as plt
import numpy as np
from scipy import misc
import fiona
from shapely.geometry import shape
import shapely
from rasterio.mask import mask
from pyproj import Proj, transform

import rasterio

# add the unet helpers
sys.path.append('../../')
from test_unet_helpers import *
from unet_models import unet11_MS

# torch stuff
import torch
from torch import nn
from torch.nn import functional as F
import torch
from torchvision import models, datasets
import torchvision
from torchvision.transforms import ToTensor, Normalize, Compose
from utils import variable
# Out:
# /home/ubuntu/anaconda3/envs/spatial_torch/lib/python3.5/site-packages/matplotlib/__init__.py:1067: UserWarning: Duplicate key in file "/home/ubuntu/.config/matplotlib/matplotlibrc", line #2
#   (fname, cnt))
# /home/ubuntu/anaconda3/envs/spatial_torch/lib/python3.5/site-packages/matplotlib/__init__.py:1067: UserWarning: Duplicate key in file "/home/ubuntu/.config/matplotlib/matplotlibrc", line #3
#   (fname, cnt))
# /home/ubuntu/anaconda3/envs/spatial_torch/lib/python3.5/importlib/_bootstrap.py:222: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /home/ubuntu/anaconda3/envs/spatial_torch/lib/python3.5/importlib/_bootstrap.py:222: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /home/ubuntu/anaconda3/envs/spatial_torch/lib/python3.5/importlib/_bootstrap.py:222: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)

# %%
class UNet(nn.Module):
    def __init__(self, in_channels=1, n_classes=2, depth=5, wf=6, padding=False,
                 batch_norm=False, up_mode='upconv'):
        """
        Implementation of
        U-Net: Convolutional Networks for Biomedical Image Segmentation
        (Ronneberger et al., 2015)
        https://arxiv.org/abs/1505.04597
        Using the default arguments will yield the exact version used
        in the original paper
        Args:
            in_channels (int): number of input channels
            n_classes (int): number of output channels
            depth (int): depth of the network
            wf (int): number of filters in the first layer is 2**wf
            padding (bool): if True, apply padding such that the input shape
                            is the same as the output.
                            This may introduce artifacts
            batch_norm (bool): Use BatchNorm after layers with an
                               activation function
            up_mode (str): one of 'upconv' or 'upsample'.
                           'upconv' will use transposed convolutions for
                           learned upsampling.
                           'upsample' will use bilinear upsampling.
        """
        super(UNet, self).__init__()
        assert up_mode in ('upconv', 'upsample')
        self.padding = padding
        self.depth = depth
        prev_channels = in_channels
        self.down_path = nn.ModuleList()
        for i in range(depth):
            self.down_path.append(UNetConvBlock(prev_channels, 2**(wf+i),
                                                padding, batch_norm))
            prev_channels = 2**(wf+i)

        self.up_path = nn.ModuleList()
        for i in reversed(range(depth - 1)):
            self.up_path.append(UNetUpBlock(prev_channels, 2**(wf+i), up_mode,
                                            padding, batch_norm))
            prev_channels = 2**(wf+i)

        self.last = nn.Conv2d(prev_channels, n_classes, kernel_size=1)

    def forward(self, x):
        blocks = []
        for i, down in enumerate(self.down_path):
            x = down(x)
            if i != len(self.down_path)-1:
                blocks.append(x)
                x = F.avg_pool2d(x, 2)

        for i, up in enumerate(self.up_path):
            x = up(x, blocks[-i-1])

        return self.last(x)


class UNetConvBlock(nn.Module):
    def __init__(self, in_size, out_size, padding, batch_norm):
        super(UNetConvBlock, self).__init__()
        block = []

        block.append(nn.Conv2d(in_size, out_size, kernel_size=3,
                               padding=int(padding)))
        block.append(nn.ReLU())
        if batch_norm:
            block.append(nn.BatchNorm2d(out_size))

        block.append(nn.Conv2d(out_size, out_size, kernel_size=3,
                               padding=int(padding)))
        block.append(nn.ReLU())
        if batch_norm:
            block.append(nn.BatchNorm2d(out_size))

        self.block = nn.Sequential(*block)

    def forward(self, x):
        out = self.block(x)
        return out


class UNetUpBlock(nn.Module):
    def __init__(self, in_size, out_size, up_mode, padding, batch_norm):
        super(UNetUpBlock, self).__init__()
        if up_mode == 'upconv':
            self.up = nn.ConvTranspose2d(in_size, out_size, kernel_size=2,
                                         stride=2)
        elif up_mode == 'upsample':
            self.up = nn.Sequential(nn.Upsample(mode='bilinear', scale_factor=2),
                                    nn.Conv2d(in_size, out_size, kernel_size=1))

        self.conv_block = UNetConvBlock(in_size, out_size, padding, batch_norm)

    def center_crop(self, layer, target_size):
        _, _, layer_height, layer_width = layer.size()
        diff_y = (layer_height - target_size[0]) // 2
        diff_x = (layer_width - target_size[1]) // 2
        return layer[:, :, diff_y:(diff_y + target_size[0]), diff_x:(diff_x + target_size[1])]

    def forward(self, x, bridge):
        up = self.up(x)
        crop1 = self.center_crop(bridge, up.shape[2:])
        out = torch.cat([up, crop1], 1)
        out = self.conv_block(out)

        return out

from glob import glob
class DG_GT_Dataset(Dataset):
    """Dataset class for ignition types (Y var)"""
    
    def __init__(self, data_dir, channels='all', img_transform=None, gt_transform=None):
        """ 
        Args:
            data_dir (string): the folder containing the image files
            channels (string): 'all', 'bgr', 'bgrn1', 'bgrn2'; band sets for DG imagery
            img_transform (callable, optional): Optional transform to  be applied to source image data
            gt_transform (callable, optional): Optional transform to  be applied to labeled image data
            x_var (iterable, optional): list of predictor variable names
            land_mask (string, optional): defines whether or not to return land mask
        """
        
        # some sanity checks
        assert os.path.exists(data_dir)
        
        self.gt_files = sorted(glob(data_dir + '/gt*.tif'))
        self.img_files = sorted(glob(data_dir + '/dg*.tif'))
        
        
        print(self.img_files[0])
        print(self.gt_files[0])
        
        self.img_transform = img_transform
        self.gt_transform = gt_transform
        self.dg_bgr = [1,2,4]
        self.dg_bgrn1 = [1,2,4,6]
        self.dg_bgrn2 = [1,2,4,7]
        self.channels = channels
        
        assert len(self.img_files) == len(self.gt_files)
        
    
    def __getitem__(self, idx):
        
        """
            Files are organized as <var_type>_<year>_<month>_t<tileNumber>.tif, e.g., Arson_1992_1_t1
            A single dataset needs to be constructed for a given ignition type, year, month, and tile number
        """
        
        img_file = self.img_files[idx]
        gt_file = self.gt_files[idx]
        
        with rio.open(img_file) as src:
            img_arr = src.read()
            
        # check the channels
        if self.channels == 'bgr':
            img_arr = img_arr[self.dg_bgr, :, :]
        elif self.channels == 'bgrn1':
            img_arr = img_arr[self.dg_bgrn1, :, :]
        elif self.channels == 'bgrn2':
            img_arr = img_arr[self.dg_bgrn2, :, :]
        else:
            pass
            
        with rio.open(gt_file) as src:
            gt_arr = src.read()

        if (self.img_transform is not None):
            return (self.img_transform(torch.from_numpy(img_arr)), 
                    self.gt_transform(torch.from_numpy(gt_arr)))   
        else:
            return (torch.from_numpy(img_arr), torch.from_numpy(gt_arr)) # return X, Y, Mask (Mask uses LandMask in X-var folder)
        
        
    def __len__(self):
        return len(self.img_files)

# %% [markdown]
# # Now that data is ready, set up the model and run through it

# %% [markdown]
# ## some code for saving the model

# %%
from datetime import datetime

def write_event(log, step: int, **data):
    data['step'] = step
    data['dt'] = datetime.now().isoformat()
    log.write(json.dumps(data, sort_keys=True))
    log.write('\n')
    log.flush()
    
save = lambda ep: torch.save({
        'model': model.state_dict(),
        'epoch': ep,
        'step': step,
    }, str(model_path))

# %% [markdown]
# ## some code for setting up the model and performance eval

# %%
import utils as pyt_utils
from torch.optim import Adam
import torch.backends.cudnn as cudnn
from pathlib import Path
from validation import validation_binary
from loss import LossBinary
import json

import time
from sklearn.metrics import roc_auc_score, log_loss, roc_auc_score, roc_curve, auc

# need to change this to DICE loss!
#loss = LossBinary(jaccard_weight=args.jaccard_weight)
#criterion = nn.CrossEntropyLoss()


cudnn.benchmark = True
# Out:
# /home/ubuntu/anaconda3/envs/spatial_torch/lib/python3.5/importlib/_bootstrap.py:222: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /home/ubuntu/anaconda3/envs/spatial_torch/lib/python3.5/importlib/_bootstrap.py:222: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)

# %% [markdown]
# # DO the same for pansharpened data

# %%
train_folder = r'D:\projects\RD\debug_IS_segmentation\tilesPS_d10000_512x512\train'
test_folder = r'D:\projects\RD\debug_IS_segmentation\tilesPS_d10000_512x512\test'
val_folder = r'D:\projects\RD\debug_IS_segmentation\tilesPS_d10000_512x512\val'

# ubuntu paths
train_folder = '/media/joemcglinchy/Data/projects/RD/debug_IS_segmentation/kmeans3_split/tilesPS_d10000_512x512/train'
test_folder = '/media/joemcglinchy/Data/projects/RD/debug_IS_segmentation/kmeans3_split/tilesPS_d10000_512x512/test'
val_folder = '/media/joemcglinchy/Data/projects/RD/debug_IS_segmentation/kmeans3_split/tilesPS_d10000_512x512/val'

# aws pathts
train_folder = '../../../tiles/kmeans3_split/tilesPS_d10000_512x512/train'
test_folder = '../../../tiles/kmeans3_split/tilesPS_d10000_512x512/test'
val_folder = '../../../tiles/kmeans3_split/tilesPS_d10000_512x512/val'

# load as 3 band
ps_train_ds = DG_GT_Dataset(train_folder)
ps_test_ds = DG_GT_Dataset(test_folder)
ps_val_ds = DG_GT_Dataset(val_folder)
# Out:
# ../../../tiles/kmeans3_split/tilesPS_d10000_512x512/train/dg_is_00000.tif
# ../../../tiles/kmeans3_split/tilesPS_d10000_512x512/train/gt_is_00000.tif
# ../../../tiles/kmeans3_split/tilesPS_d10000_512x512/test/dg_is_00731.tif
# ../../../tiles/kmeans3_split/tilesPS_d10000_512x512/test/gt_is_00731.tif
# ../../../tiles/kmeans3_split/tilesPS_d10000_512x512/val/dg_is_00500.tif
# ../../../tiles/kmeans3_split/tilesPS_d10000_512x512/val/gt_is_00500.tif

# %%
# iterate over some batch sizes
times = []
# batch_sizes = [50, 100, 200,300,400,500,600,700,800,900,1000]
# smaller batch sizes as per https://stats.stackexchange.com/questions/164876/tradeoff-batch-size-vs-number-of-iterations-to-train-a-neural-network
#model = unet11_MS(num_bands=4, pretrained=False)

# set some parameters
lr = 0.0001
bsize = 24 # was 32

#ps_model = UNet(in_channels=8, n_classes=1, depth=5, wf=6, padding=True, batch_norm=False, up_mode='upconv')
ps_model = unet11_MS(num_bands=8, pretrained=False)

ps_optimizer = Adam(ps_model.parameters(), lr=lr)
ps_criterion = LossBinary(jaccard_weight=1.0)

###### specify DataLoaders
n_workers=4 # for some unknown reason, 0 is enabling all GPUs when 4 had previously done the trick. could be slower.
ps_train_dl = DataLoader(ps_train_ds, batch_size=bsize, shuffle=True, num_workers=n_workers)
ps_test_dl = DataLoader(ps_test_ds, batch_size=bsize, shuffle=True, num_workers=n_workers)


# make model parallel and on GPU
# device=torch.device("cpu")
device = torch.device("cuda" if torch.cuda.is_available() else "cpu") # get device for gpu or cpu
if torch.cuda.device_count() >= 1:
    print("Let's use", torch.cuda.device_count(), "GPUs!")
    ps_model = nn.DataParallel(ps_model)
    ps_model.to(device)
# Out:
# num_bands is  8
# Let's use 4 GPUs!

# %%
device
# Out:
# device(type='cuda')

# %%
print('batchsize, ', bsize)
ps_mean_loss = 0.0
ps_running_loss = 0.0
print('training...')

ps_losses=[]
ps_losses_ep = []
#tl = zip(dg_dl_train, gt_dl_train)
ps_step=0
# record time for one epoch
ps_rocs = []

#####################################################

t0 = time.time()
num_epochs = 100
for epoch in range(num_epochs):
    
#     try:
    te = time.time()

    epoch_i = epoch+1
    print('on epoch {}'.format(epoch_i))

    running_loss = 0
    for i, (inputs_, targets_) in enumerate(ps_train_dl):

        #print('hi')

        # get the inputs
        targets_ = targets_.type(torch.FloatTensor)

        #inputs, targets = variable(inputs_).cuda(), variable(targets_).cuda()
        inputs, targets = variable(inputs_), variable(targets_)
        inputs.to(device)
        targets.to(device)

        outputs = ps_model(inputs)

        # zero parameter gradients
        ps_optimizer.zero_grad()

        # forward + backward + optimize            
        i_loss = ps_criterion(outputs, targets)                
        i_loss.backward()
        ps_optimizer.step()
        ps_step+=1

        running_loss += i_loss
        
        if i%5 == 0: # print/store every 10
            ps_losses.append(i_loss)
            #running_loss += i_loss
            #print('[%d, %5d] loss: %.3f' %(epoch, i + 1, i_loss))

    # get some numbers for the ROC curve
    if epoch_i%2 == 0:
        pred_y = outputs.cpu().data.numpy().squeeze().flatten()
        target_y = targets.cpu().data.numpy().flatten()
        tu = (i_loss, roc_auc_score(target_y,pred_y ))
        print ('epoch: {}, LOSS={}, ROC_AUC={} '.format(epoch_i, *tu))  
        ps_rocs.append(tu[1])


    ps_losses_ep.append(running_loss)
    te1 = time.time()
    print('time for epoch {}: {} seconds'.format(epoch_i, te1-te))

    # early exit critera
    if len(ps_rocs)>2:
        if (np.abs(ps_rocs[-1] - ps_rocs[-2]) < 0.009) and (ps_rocs[-1] > 0.98):
            print('area under curve not changing significantly, exit loop')
            break_flag = False
            
            if break_flag:
                break

#     except Exception as e:
#         print('something happened')
#         print(e)
#         break
        
        
t1 = time.time()
print ('total time: ',t1 - t0)
times.append(t1-t0)
# Out:
# batchsize,  24
# training...
# on epoch 1
# /home/ubuntu/anaconda3/envs/spatial_torch/lib/python3.5/site-packages/torch/nn/functional.py:1006: UserWarning: nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.
#   warnings.warn("nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.")
# time for epoch 1: 28.610695600509644 seconds
# on epoch 2
# epoch: 2, LOSS=1.2471115589141846, ROC_AUC=0.7076918371169704
# time for epoch 2: 10.046640634536743 seconds
# on epoch 3
# time for epoch 3: 8.039083003997803 seconds
# on epoch 4
# epoch: 4, LOSS=0.9823541641235352, ROC_AUC=0.8614188386808408
# time for epoch 4: 10.34372854232788 seconds
# on epoch 5
# time for epoch 5: 8.008946180343628 seconds
# on epoch 6
# epoch: 6, LOSS=0.8006734848022461, ROC_AUC=0.9119009200641081
# time for epoch 6: 9.956794500350952 seconds
# on epoch 7
# time for epoch 7: 8.010390043258667 seconds
# on epoch 8
# epoch: 8, LOSS=0.7763894200325012, ROC_AUC=0.8983019077045447
# time for epoch 8: 10.653596639633179 seconds
# on epoch 9
# time for epoch 9: 8.132498264312744 seconds
# on epoch 10
# epoch: 10, LOSS=0.867702305316925, ROC_AUC=0.9029245192191702
# time for epoch 10: 9.97722339630127 seconds
# on epoch 11
# time for epoch 11: 8.056004524230957 seconds
# on epoch 12
# epoch: 12, LOSS=0.7214196920394897, ROC_AUC=0.9150794316502953
# time for epoch 12: 9.90996265411377 seconds
# on epoch 13
# time for epoch 13: 8.225245237350464 seconds
# on epoch 14
# epoch: 14, LOSS=0.560447096824646, ROC_AUC=0.9322208782548573
# time for epoch 14: 9.95193076133728 seconds
# on epoch 15
# time for epoch 15: 8.074388027191162 seconds
# on epoch 16
# epoch: 16, LOSS=0.7253650426864624, ROC_AUC=0.908782194955283
# time for epoch 16: 9.956876516342163 seconds
# on epoch 17
# time for epoch 17: 8.138579607009888 seconds
# on epoch 18
# epoch: 18, LOSS=0.6348488330841064, ROC_AUC=0.9221712934327275
# time for epoch 18: 9.922835111618042 seconds
# on epoch 19
# time for epoch 19: 8.329119443893433 seconds
# on epoch 20
# epoch: 20, LOSS=0.6450463533401489, ROC_AUC=0.9154763314940408
# time for epoch 20: 9.942452430725098 seconds
# on epoch 21
# time for epoch 21: 8.004181146621704 seconds
# on epoch 22
# epoch: 22, LOSS=0.5687777996063232, ROC_AUC=0.9275324060480085
# time for epoch 22: 9.940932512283325 seconds
# on epoch 23
# time for epoch 23: 8.021504878997803 seconds
# on epoch 24
# epoch: 24, LOSS=0.5390088558197021, ROC_AUC=0.9435431118462481
# time for epoch 24: 10.213388919830322 seconds
# on epoch 25
# time for epoch 25: 8.38178539276123 seconds
# on epoch 26
# epoch: 26, LOSS=0.47504445910453796, ROC_AUC=0.9612331777116258
# time for epoch 26: 10.097343444824219 seconds
# on epoch 27
# time for epoch 27: 8.31846833229065 seconds
# on epoch 28
# epoch: 28, LOSS=0.5605416297912598, ROC_AUC=0.9451705951597288
# time for epoch 28: 9.891089677810669 seconds
# on epoch 29
# time for epoch 29: 8.207393646240234 seconds
# on epoch 30
# epoch: 30, LOSS=0.45315438508987427, ROC_AUC=0.9610383076398349
# time for epoch 30: 9.943293809890747 seconds
# on epoch 31
# time for epoch 31: 8.016103982925415 seconds
# on epoch 32
# epoch: 32, LOSS=0.40725448727607727, ROC_AUC=0.9673828677906228
# time for epoch 32: 10.761934041976929 seconds
# on epoch 33
# time for epoch 33: 8.05875039100647 seconds
# on epoch 34
# epoch: 34, LOSS=0.3576205372810364, ROC_AUC=0.9702287281308243
# time for epoch 34: 10.39553713798523 seconds
# on epoch 35
# time for epoch 35: 8.027648448944092 seconds
# on epoch 36
# epoch: 36, LOSS=0.45898157358169556, ROC_AUC=0.9700357854974143
# time for epoch 36: 10.315340757369995 seconds
# on epoch 37
# time for epoch 37: 8.010942459106445 seconds
# on epoch 38
# epoch: 38, LOSS=0.32280510663986206, ROC_AUC=0.9798814356386826
# time for epoch 38: 9.912149429321289 seconds
# on epoch 39
# time for epoch 39: 8.368213653564453 seconds
# on epoch 40
# epoch: 40, LOSS=0.38372480869293213, ROC_AUC=0.9754741974708534
# time for epoch 40: 10.212969064712524 seconds
# on epoch 41
# time for epoch 41: 8.022141695022583 seconds
# on epoch 42
# epoch: 42, LOSS=0.3013319671154022, ROC_AUC=0.9833632871578778
# time for epoch 42: 10.229765892028809 seconds
# area under curve not changing significantly, exit loop
# on epoch 43
# time for epoch 43: 8.02976107597351 seconds
# area under curve not changing significantly, exit loop
# on epoch 44
# epoch: 44, LOSS=0.26553457975387573, ROC_AUC=0.9854030371008369
# time for epoch 44: 9.928817510604858 seconds
# area under curve not changing significantly, exit loop
# on epoch 45
# time for epoch 45: 8.165382385253906 seconds
# area under curve not changing significantly, exit loop
# on epoch 46
# epoch: 46, LOSS=0.2754727602005005, ROC_AUC=0.9850266978527338
# time for epoch 46: 10.088305711746216 seconds
# area under curve not changing significantly, exit loop
# on epoch 47
# time for epoch 47: 8.069720268249512 seconds
# area under curve not changing significantly, exit loop
# on epoch 48
# epoch: 48, LOSS=0.27365642786026, ROC_AUC=0.9860705717056154
# time for epoch 48: 10.00308084487915 seconds
# area under curve not changing significantly, exit loop
# on epoch 49
# time for epoch 49: 8.253933191299438 seconds
# area under curve not changing significantly, exit loop
# on epoch 50
# epoch: 50, LOSS=0.2867327928543091, ROC_AUC=0.9834707404849728
# time for epoch 50: 10.211089134216309 seconds
# area under curve not changing significantly, exit loop
# on epoch 51
# time for epoch 51: 8.254927158355713 seconds
# area under curve not changing significantly, exit loop
# on epoch 52
# epoch: 52, LOSS=0.2187763750553131, ROC_AUC=0.9891935746935234
# time for epoch 52: 9.938467264175415 seconds
# area under curve not changing significantly, exit loop
# on epoch 53
# time for epoch 53: 8.161622524261475 seconds
# area under curve not changing significantly, exit loop
# on epoch 54
# epoch: 54, LOSS=0.20837457478046417, ROC_AUC=0.9902075226040968
# time for epoch 54: 9.905561208724976 seconds
# area under curve not changing significantly, exit loop
# on epoch 55
# time for epoch 55: 8.022157192230225 seconds
# area under curve not changing significantly, exit loop
# on epoch 56
# epoch: 56, LOSS=0.23233166337013245, ROC_AUC=0.9902539876654882
# time for epoch 56: 10.126249074935913 seconds
# area under curve not changing significantly, exit loop
# on epoch 57
# time for epoch 57: 8.401424169540405 seconds
# area under curve not changing significantly, exit loop
# on epoch 58
# epoch: 58, LOSS=0.18902665376663208, ROC_AUC=0.9919548325082033
# time for epoch 58: 10.294793367385864 seconds
# area under curve not changing significantly, exit loop
# on epoch 59
# time for epoch 59: 8.109298944473267 seconds
# area under curve not changing significantly, exit loop
# on epoch 60
# epoch: 60, LOSS=0.22164583206176758, ROC_AUC=0.9905367275592744
# time for epoch 60: 9.932533264160156 seconds
# area under curve not changing significantly, exit loop
# on epoch 61
# time for epoch 61: 8.06146502494812 seconds
# area under curve not changing significantly, exit loop
# on epoch 62
# epoch: 62, LOSS=0.22173483669757843, ROC_AUC=0.990541770123959
# time for epoch 62: 9.896331310272217 seconds
# area under curve not changing significantly, exit loop
# on epoch 63
# time for epoch 63: 8.09003496170044 seconds
# area under curve not changing significantly, exit loop
# on epoch 64
# epoch: 64, LOSS=0.1824849247932434, ROC_AUC=0.9926659678509873
# time for epoch 64: 10.363957643508911 seconds
# area under curve not changing significantly, exit loop
# on epoch 65
# time for epoch 65: 8.071773290634155 seconds
# area under curve not changing significantly, exit loop
# on epoch 66
# epoch: 66, LOSS=0.20037946105003357, ROC_AUC=0.9915456064996322
# time for epoch 66: 10.468547821044922 seconds
# area under curve not changing significantly, exit loop
# on epoch 67
# time for epoch 67: 8.146166324615479 seconds
# area under curve not changing significantly, exit loop
# on epoch 68
# epoch: 68, LOSS=0.2248903512954712, ROC_AUC=0.9903023152014429
# time for epoch 68: 10.059136629104614 seconds
# area under curve not changing significantly, exit loop
# on epoch 69
# time for epoch 69: 8.110098838806152 seconds
# area under curve not changing significantly, exit loop
# on epoch 70
# epoch: 70, LOSS=0.15668363869190216, ROC_AUC=0.9933086677447523
# time for epoch 70: 10.154160737991333 seconds
# area under curve not changing significantly, exit loop
# on epoch 71
# time for epoch 71: 8.055410861968994 seconds
# area under curve not changing significantly, exit loop
# on epoch 72
# epoch: 72, LOSS=0.1492532342672348, ROC_AUC=0.9950713308043512
# time for epoch 72: 10.198420524597168 seconds
# area under curve not changing significantly, exit loop
# on epoch 73
# time for epoch 73: 8.368321180343628 seconds
# area under curve not changing significantly, exit loop
# on epoch 74
# epoch: 74, LOSS=0.1638147532939911, ROC_AUC=0.994786699107458
# time for epoch 74: 9.983452320098877 seconds
# area under curve not changing significantly, exit loop
# on epoch 75
# time for epoch 75: 8.039616346359253 seconds
# area under curve not changing significantly, exit loop
# on epoch 76
# epoch: 76, LOSS=0.13575223088264465, ROC_AUC=0.9960860632190746
# time for epoch 76: 9.859628915786743 seconds
# area under curve not changing significantly, exit loop
# on epoch 77
# time for epoch 77: 8.02767014503479 seconds
# area under curve not changing significantly, exit loop
# on epoch 78
# epoch: 78, LOSS=0.16775666177272797, ROC_AUC=0.9936081624867021
# time for epoch 78: 10.18622612953186 seconds
# area under curve not changing significantly, exit loop
# on epoch 79
# time for epoch 79: 8.455031156539917 seconds
# area under curve not changing significantly, exit loop
# on epoch 80
# epoch: 80, LOSS=0.183958500623703, ROC_AUC=0.9930335591971033
# time for epoch 80: 10.142168998718262 seconds
# area under curve not changing significantly, exit loop
# on epoch 81
# time for epoch 81: 8.072701454162598 seconds
# area under curve not changing significantly, exit loop
# on epoch 82
# epoch: 82, LOSS=0.19201788306236267, ROC_AUC=0.9934833411019676
# time for epoch 82: 10.208920001983643 seconds
# area under curve not changing significantly, exit loop
# on epoch 83
# time for epoch 83: 8.043544292449951 seconds
# area under curve not changing significantly, exit loop
# on epoch 84
# epoch: 84, LOSS=0.16920766234397888, ROC_AUC=0.9940038765145767
# time for epoch 84: 10.123324871063232 seconds
# area under curve not changing significantly, exit loop
# on epoch 85
# time for epoch 85: 8.038078546524048 seconds
# area under curve not changing significantly, exit loop
# on epoch 86
# epoch: 86, LOSS=0.21180030703544617, ROC_AUC=0.9929552449765536
# time for epoch 86: 10.244700908660889 seconds
# area under curve not changing significantly, exit loop
# on epoch 87
# time for epoch 87: 8.105156421661377 seconds
# area under curve not changing significantly, exit loop
# on epoch 88
# epoch: 88, LOSS=0.16152343153953552, ROC_AUC=0.9940880577326464
# time for epoch 88: 10.349518060684204 seconds
# area under curve not changing significantly, exit loop
# on epoch 89
# time for epoch 89: 8.465107440948486 seconds
# area under curve not changing significantly, exit loop
# on epoch 90
# epoch: 90, LOSS=0.11542128771543503, ROC_AUC=0.9973422520616596
# time for epoch 90: 10.189577102661133 seconds
# area under curve not changing significantly, exit loop
# on epoch 91
# time for epoch 91: 8.433441638946533 seconds
# area under curve not changing significantly, exit loop
# on epoch 92
# epoch: 92, LOSS=0.16495925188064575, ROC_AUC=0.9945471106987146
# time for epoch 92: 10.40221118927002 seconds
# area under curve not changing significantly, exit loop
# on epoch 93
# time for epoch 93: 8.118510246276855 seconds
# area under curve not changing significantly, exit loop
# on epoch 94
# epoch: 94, LOSS=0.14118137955665588, ROC_AUC=0.9957542283131504
# time for epoch 94: 10.409064769744873 seconds
# area under curve not changing significantly, exit loop
# on epoch 95
# time for epoch 95: 8.478864908218384 seconds
# area under curve not changing significantly, exit loop
# on epoch 96
# epoch: 96, LOSS=0.139896959066391, ROC_AUC=0.9954048354184779
# time for epoch 96: 9.904469728469849 seconds
# area under curve not changing significantly, exit loop
# on epoch 97
# time for epoch 97: 8.048644065856934 seconds
# area under curve not changing significantly, exit loop
# on epoch 98
# epoch: 98, LOSS=0.14596250653266907, ROC_AUC=0.9959877330304481
# time for epoch 98: 10.200108289718628 seconds
# area under curve not changing significantly, exit loop
# on epoch 99
# time for epoch 99: 8.408363819122314 seconds
# area under curve not changing significantly, exit loop
# on epoch 100
# epoch: 100, LOSS=0.1349417120218277, ROC_AUC=0.9964565887490283
# time for epoch 100: 9.97958755493164 seconds
# area under curve not changing significantly, exit loop
# total time:  934.5360131263733

# %%
plt.plot(ps_losses)
plt.show()

plt.plot(ps_rocs)
plt.show()

plt.plot(ps_losses_ep)
plt.show()
# Out:
# /home/ubuntu/anaconda3/envs/spatial_torch/lib/python3.5/site-packages/matplotlib/font_manager.py:1328: UserWarning: findfont: Font family ['normal'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
ps_model.eval()
for ind in range(1,20):
    fig, ax = plt.subplots(1,3, figsize=(10,5))
    test_im, test_target = ps_test_ds[ind]
    test_out = ps_model(variable(test_im.unsqueeze(0)))
    ax[0].imshow(test_target.numpy()[0])

    out = test_out.cpu().detach().numpy()[0][0]
    ax[1].imshow(out)

    ax[2].imshow(out>0)
    #ax[2].imshow(test_im.unsqueeze(0).cpu().detach().numpy()[0][0])
    plt.show()
    
    false_positive_rate, true_positive_rate, thresholds = roc_curve(test_target.numpy().flatten(), out.flatten())
    roc_auc = auc(false_positive_rate, true_positive_rate)
    plt.plot(false_positive_rate, true_positive_rate)
    plt.title('AUC: {}'.format(roc_auc))
# Out:
# /home/ubuntu/anaconda3/envs/spatial_torch/lib/python3.5/site-packages/matplotlib/font_manager.py:1328: UserWarning: findfont: Font family ['normal'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %% [markdown]
# ## save the model, AUC, and loss vectors

# %%
save_res = False

if save_res:
    # directory
    save_dir = 'files_PS_bgrn1'
    if not os.path.exists(save_dir):
        os.makedirs(save_dir)

    # save the model
    model_path = 'bgrn1_ps_ep{}_step{}_b{}.pt'.format(num_epochs, step, bsize)
    model_path = os.path.join(save_dir, model_path)
    save = lambda ep: torch.save({
            'model': model.state_dict(),
            'epoch': ep,
            'step': step,
        }, str(model_path))

    save(model_path)

    # save the AUCs
    auc_path = 'auc_bgrn1_ps_ep{}_step{}_b{}.txt'.format(num_epochs, step, bsize)
    auc_path = os.path.join(save_dir, auc_path)
    np.savetxt(auc_path, np.array(rocs))

    #save the loss vectors
    ep_loss_path = 'losses_ep_bgrn1_ps_ep{}_step{}_b{}.txt'.format(num_epochs, step, bsize)
    ep_loss_path = os.path.join(save_dir, ep_loss_path)
    np.savetxt(ep_loss_path, np.array(losses_ep))

    #save the total loss vector
    loss_path = 'loss_bgrn1_ps_ep{}_step{}_b{}.txt'.format(num_epochs, step, bsize)
    loss_path = os.path.join(save_dir, loss_path)
    np.savetxt(loss_path, np.array(losses))
