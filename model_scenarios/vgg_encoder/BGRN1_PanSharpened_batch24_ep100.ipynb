# %%
from glob import glob

# %matplotlib inline
from pylab import *
# import cv2
import rasterio as rio

rcParams['figure.figsize'] = 10, 10

font = {'family' : 'normal',
        'weight' : 'medium',
        'size'   : 14}

matplotlib.rc('font', **font)

import os,sys
from matplotlib import pyplot as plt
import numpy as np
from scipy import misc
import fiona
from shapely.geometry import shape
import shapely
from rasterio.mask import mask
from pyproj import Proj, transform

import rasterio

# add the unet helpers
sys.path.append('../../')
from test_unet_helpers import *
from unet_models import unet11_MS

# torch stuff
import torch
from torch import nn
from torch.nn import functional as F
import torch
from torchvision import models, datasets
import torchvision
from torchvision.transforms import ToTensor, Normalize, Compose
from utils import variable
# Out:
# /home/ubuntu/anaconda3/envs/spatial_torch/lib/python3.5/site-packages/matplotlib/__init__.py:1067: UserWarning: Duplicate key in file "/home/ubuntu/.config/matplotlib/matplotlibrc", line #2
#   (fname, cnt))
# /home/ubuntu/anaconda3/envs/spatial_torch/lib/python3.5/site-packages/matplotlib/__init__.py:1067: UserWarning: Duplicate key in file "/home/ubuntu/.config/matplotlib/matplotlibrc", line #3
#   (fname, cnt))
# /home/ubuntu/anaconda3/envs/spatial_torch/lib/python3.5/importlib/_bootstrap.py:222: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /home/ubuntu/anaconda3/envs/spatial_torch/lib/python3.5/importlib/_bootstrap.py:222: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /home/ubuntu/anaconda3/envs/spatial_torch/lib/python3.5/importlib/_bootstrap.py:222: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)

# %%
class UNet(nn.Module):
    def __init__(self, in_channels=1, n_classes=2, depth=5, wf=6, padding=False,
                 batch_norm=False, up_mode='upconv'):
        """
        Implementation of
        U-Net: Convolutional Networks for Biomedical Image Segmentation
        (Ronneberger et al., 2015)
        https://arxiv.org/abs/1505.04597
        Using the default arguments will yield the exact version used
        in the original paper
        Args:
            in_channels (int): number of input channels
            n_classes (int): number of output channels
            depth (int): depth of the network
            wf (int): number of filters in the first layer is 2**wf
            padding (bool): if True, apply padding such that the input shape
                            is the same as the output.
                            This may introduce artifacts
            batch_norm (bool): Use BatchNorm after layers with an
                               activation function
            up_mode (str): one of 'upconv' or 'upsample'.
                           'upconv' will use transposed convolutions for
                           learned upsampling.
                           'upsample' will use bilinear upsampling.
        """
        super(UNet, self).__init__()
        assert up_mode in ('upconv', 'upsample')
        self.padding = padding
        self.depth = depth
        prev_channels = in_channels
        self.down_path = nn.ModuleList()
        for i in range(depth):
            self.down_path.append(UNetConvBlock(prev_channels, 2**(wf+i),
                                                padding, batch_norm))
            prev_channels = 2**(wf+i)

        self.up_path = nn.ModuleList()
        for i in reversed(range(depth - 1)):
            self.up_path.append(UNetUpBlock(prev_channels, 2**(wf+i), up_mode,
                                            padding, batch_norm))
            prev_channels = 2**(wf+i)

        self.last = nn.Conv2d(prev_channels, n_classes, kernel_size=1)

    def forward(self, x):
        blocks = []
        for i, down in enumerate(self.down_path):
            x = down(x)
            if i != len(self.down_path)-1:
                blocks.append(x)
                x = F.avg_pool2d(x, 2)

        for i, up in enumerate(self.up_path):
            x = up(x, blocks[-i-1])

        return self.last(x)


class UNetConvBlock(nn.Module):
    def __init__(self, in_size, out_size, padding, batch_norm):
        super(UNetConvBlock, self).__init__()
        block = []

        block.append(nn.Conv2d(in_size, out_size, kernel_size=3,
                               padding=int(padding)))
        block.append(nn.ReLU())
        if batch_norm:
            block.append(nn.BatchNorm2d(out_size))

        block.append(nn.Conv2d(out_size, out_size, kernel_size=3,
                               padding=int(padding)))
        block.append(nn.ReLU())
        if batch_norm:
            block.append(nn.BatchNorm2d(out_size))

        self.block = nn.Sequential(*block)

    def forward(self, x):
        out = self.block(x)
        return out


class UNetUpBlock(nn.Module):
    def __init__(self, in_size, out_size, up_mode, padding, batch_norm):
        super(UNetUpBlock, self).__init__()
        if up_mode == 'upconv':
            self.up = nn.ConvTranspose2d(in_size, out_size, kernel_size=2,
                                         stride=2)
        elif up_mode == 'upsample':
            self.up = nn.Sequential(nn.Upsample(mode='bilinear', scale_factor=2),
                                    nn.Conv2d(in_size, out_size, kernel_size=1))

        self.conv_block = UNetConvBlock(in_size, out_size, padding, batch_norm)

    def center_crop(self, layer, target_size):
        _, _, layer_height, layer_width = layer.size()
        diff_y = (layer_height - target_size[0]) // 2
        diff_x = (layer_width - target_size[1]) // 2
        return layer[:, :, diff_y:(diff_y + target_size[0]), diff_x:(diff_x + target_size[1])]

    def forward(self, x, bridge):
        up = self.up(x)
        crop1 = self.center_crop(bridge, up.shape[2:])
        out = torch.cat([up, crop1], 1)
        out = self.conv_block(out)

        return out

from glob import glob
class DG_GT_Dataset(Dataset):
    """Dataset class for ignition types (Y var)"""
    
    def __init__(self, data_dir, channels='all', img_transform=None, gt_transform=None):
        """ 
        Args:
            data_dir (string): the folder containing the image files
            channels (string): 'all', 'bgr', 'bgrn1', 'bgrn2'; band sets for DG imagery
            img_transform (callable, optional): Optional transform to  be applied to source image data
            gt_transform (callable, optional): Optional transform to  be applied to labeled image data
            x_var (iterable, optional): list of predictor variable names
            land_mask (string, optional): defines whether or not to return land mask
        """
        
        # some sanity checks
        assert os.path.exists(data_dir)
        
        self.gt_files = sorted(glob(data_dir + '/gt*.tif'))
        self.img_files = sorted(glob(data_dir + '/dg*.tif'))
        
        
        print(self.img_files[0])
        print(self.gt_files[0])
        
        self.img_transform = img_transform
        self.gt_transform = gt_transform
        self.dg_bgr = [1,2,4]
        self.dg_bgrn1 = [1,2,4,6]
        self.dg_bgrn2 = [1,2,4,7]
        self.channels = channels
        
        assert len(self.img_files) == len(self.gt_files)
        
    
    def __getitem__(self, idx):
        
        """
            Files are organized as <var_type>_<year>_<month>_t<tileNumber>.tif, e.g., Arson_1992_1_t1
            A single dataset needs to be constructed for a given ignition type, year, month, and tile number
        """
        
        img_file = self.img_files[idx]
        gt_file = self.gt_files[idx]
        
        with rio.open(img_file) as src:
            img_arr = src.read()
            
        # check the channels
        if self.channels == 'bgr':
            img_arr = img_arr[self.dg_bgr, :, :]
        elif self.channels == 'bgrn1':
            img_arr = img_arr[self.dg_bgrn1, :, :]
        elif self.channels == 'bgrn2':
            img_arr = img_arr[self.dg_brgn2, :, :]
        else:
            pass
            
        with rio.open(gt_file) as src:
            gt_arr = src.read()

        if (self.img_transform is not None):
            return (self.img_transform(torch.from_numpy(img_arr)), 
                    self.gt_transform(torch.from_numpy(gt_arr)))   
        else:
            return (torch.from_numpy(img_arr), torch.from_numpy(gt_arr)) # return X, Y, Mask (Mask uses LandMask in X-var folder)
        
        
    def __len__(self):
        return len(self.img_files)

# %% [markdown]
# # Now that data is ready, set up the model and run through it

# %% [markdown]
# ## some code for saving the model

# %%
from datetime import datetime

def write_event(log, step: int, **data):
    data['step'] = step
    data['dt'] = datetime.now().isoformat()
    log.write(json.dumps(data, sort_keys=True))
    log.write('\n')
    log.flush()
    
save = lambda ep: torch.save({
        'model': model.state_dict(),
        'epoch': ep,
        'step': step,
    }, str(model_path))

# %% [markdown]
# ## some code for setting up the model and performance eval

# %%
import utils as pyt_utils
from torch.optim import Adam
import torch.backends.cudnn as cudnn
from pathlib import Path
from validation import validation_binary
from loss import LossBinary
import json

import time
from sklearn.metrics import roc_auc_score, log_loss, roc_auc_score, roc_curve, auc

# need to change this to DICE loss!
#loss = LossBinary(jaccard_weight=args.jaccard_weight)
#criterion = nn.CrossEntropyLoss()


cudnn.benchmark = True
# Out:
# /home/ubuntu/anaconda3/envs/spatial_torch/lib/python3.5/importlib/_bootstrap.py:222: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /home/ubuntu/anaconda3/envs/spatial_torch/lib/python3.5/importlib/_bootstrap.py:222: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)

# %% [markdown]
# # DO the same for pansharpened data

# %%
train_folder = r'D:\projects\RD\debug_IS_segmentation\tilesPS_d10000_512x512\train'
test_folder = r'D:\projects\RD\debug_IS_segmentation\tilesPS_d10000_512x512\test'
val_folder = r'D:\projects\RD\debug_IS_segmentation\tilesPS_d10000_512x512\val'

# ubuntu paths
train_folder = '/media/joemcglinchy/Data/projects/RD/debug_IS_segmentation/kmeans3_split/tilesPS_d10000_512x512/train'
test_folder = '/media/joemcglinchy/Data/projects/RD/debug_IS_segmentation/kmeans3_split/tilesPS_d10000_512x512/test'
val_folder = '/media/joemcglinchy/Data/projects/RD/debug_IS_segmentation/kmeans3_split/tilesPS_d10000_512x512/val'

# aws pathts
train_folder = '../../../tiles/kmeans3_split/tilesPS_d10000_512x512/train'
test_folder = '../../../tiles/kmeans3_split/tilesPS_d10000_512x512/test'
val_folder = '../../../tiles/kmeans3_split/tilesPS_d10000_512x512/val'

# load as 4 band
ps_train_ds = DG_GT_Dataset(train_folder, channels='bgrn1')
ps_test_ds = DG_GT_Dataset(test_folder, channels='bgrn1')
ps_val_ds = DG_GT_Dataset(val_folder, channels='bgrn1')
# Out:
# ../../../tiles/kmeans3_split/tilesPS_d10000_512x512/train/dg_is_00000.tif
# ../../../tiles/kmeans3_split/tilesPS_d10000_512x512/train/gt_is_00000.tif
# ../../../tiles/kmeans3_split/tilesPS_d10000_512x512/test/dg_is_00731.tif
# ../../../tiles/kmeans3_split/tilesPS_d10000_512x512/test/gt_is_00731.tif
# ../../../tiles/kmeans3_split/tilesPS_d10000_512x512/val/dg_is_00500.tif
# ../../../tiles/kmeans3_split/tilesPS_d10000_512x512/val/gt_is_00500.tif

# %%
# iterate over some batch sizes
times = []
# batch_sizes = [50, 100, 200,300,400,500,600,700,800,900,1000]
# smaller batch sizes as per https://stats.stackexchange.com/questions/164876/tradeoff-batch-size-vs-number-of-iterations-to-train-a-neural-network
#model = unet11_MS(num_bands=4, pretrained=False)

# set some parameters
lr = 0.0001
bsize = 24 # was 32

#ps_model = UNet(in_channels=4, n_classes=1, depth=5, wf=6, padding=True, batch_norm=False, up_mode='upconv')
ps_model = unet11_MS(num_bands=4, pretrained=False)

ps_optimizer = Adam(ps_model.parameters(), lr=lr)
ps_criterion = LossBinary(jaccard_weight=1.0)

###### specify DataLoaders
n_workers=4 # for some unknown reason, 0 is enabling all GPUs when 4 had previously done the trick. could be slower.
ps_train_dl = DataLoader(ps_train_ds, batch_size=bsize, shuffle=True, num_workers=n_workers)
ps_test_dl = DataLoader(ps_test_ds, batch_size=bsize, shuffle=True, num_workers=n_workers)


# make model parallel and on GPU
# device=torch.device("cpu")
device = torch.device("cuda" if torch.cuda.is_available() else "cpu") # get device for gpu or cpu
if torch.cuda.device_count() >= 1:
    print("Let's use", torch.cuda.device_count(), "GPUs!")
    ps_model = nn.DataParallel(ps_model)
    ps_model.to(device)
# Out:
# num_bands is  4
# Let's use 4 GPUs!

# %%
device
# Out:
# device(type='cuda')

# %%
print('batchsize, ', bsize)
ps_mean_loss = 0.0
ps_running_loss = 0.0
print('training...')

ps_losses=[]
ps_losses_ep = []
#tl = zip(dg_dl_train, gt_dl_train)
ps_step=0
# record time for one epoch
ps_rocs = []

#####################################################

t0 = time.time()
num_epochs = 100
for epoch in range(num_epochs):
    
#     try:
    te = time.time()

    epoch_i = epoch+1
    print('on epoch {}'.format(epoch_i))

    running_loss = 0
    for i, (inputs_, targets_) in enumerate(ps_train_dl):

        #print('hi')

        # get the inputs
        targets_ = targets_.type(torch.FloatTensor)

        #inputs, targets = variable(inputs_).cuda(), variable(targets_).cuda()
        inputs, targets = variable(inputs_), variable(targets_)
        inputs.to(device)
        targets.to(device)

        outputs = ps_model(inputs)

        # zero parameter gradients
        ps_optimizer.zero_grad()

        # forward + backward + optimize            
        i_loss = ps_criterion(outputs, targets)                
        i_loss.backward()
        ps_optimizer.step()
        ps_step+=1

        running_loss += i_loss
        
        if i%5 == 0: # print/store every 10
            ps_losses.append(i_loss)
            #running_loss += i_loss
            #print('[%d, %5d] loss: %.3f' %(epoch, i + 1, i_loss))

    # get some numbers for the ROC curve
    if epoch_i%2 == 0:
        pred_y = outputs.cpu().data.numpy().squeeze().flatten()
        target_y = targets.cpu().data.numpy().flatten()
        tu = (i_loss, roc_auc_score(target_y,pred_y ))
        print ('epoch: {}, LOSS={}, ROC_AUC={} '.format(epoch_i, *tu))  
        ps_rocs.append(tu[1])


    ps_losses_ep.append(running_loss)
    te1 = time.time()
    print('time for epoch {}: {} seconds'.format(epoch_i, te1-te))

    # early exit critera
    if len(ps_rocs)>2:
        if (np.abs(ps_rocs[-1] - ps_rocs[-2]) < 0.009) and (ps_rocs[-1] > 0.98):
            print('area under curve not changing significantly, exit loop')
            break_flag = False
            
            if break_flag:
                break

#     except Exception as e:
#         print('something happened')
#         print(e)
#         break
        
        
t1 = time.time()
print ('total time: ',t1 - t0)
times.append(t1-t0)
# Out:
# batchsize,  24
# training...
# on epoch 1
# /home/ubuntu/anaconda3/envs/spatial_torch/lib/python3.5/site-packages/torch/nn/functional.py:1006: UserWarning: nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.
#   warnings.warn("nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.")
# time for epoch 1: 27.323946714401245 seconds
# on epoch 2
# epoch: 2, LOSS=1.0500980615615845, ROC_AUC=0.7183712903723234
# time for epoch 2: 9.539686441421509 seconds
# on epoch 3
# time for epoch 3: 7.799607753753662 seconds
# on epoch 4
# epoch: 4, LOSS=1.0047086477279663, ROC_AUC=0.8106888237444777
# time for epoch 4: 9.537486791610718 seconds
# on epoch 5
# time for epoch 5: 7.5925328731536865 seconds
# on epoch 6
# epoch: 6, LOSS=0.8815574645996094, ROC_AUC=0.8493665301050595
# time for epoch 6: 9.450469970703125 seconds
# on epoch 7
# time for epoch 7: 7.80722975730896 seconds
# on epoch 8
# epoch: 8, LOSS=0.6972445249557495, ROC_AUC=0.9090450544781726
# time for epoch 8: 9.443624019622803 seconds
# on epoch 9
# time for epoch 9: 7.710191249847412 seconds
# on epoch 10
# epoch: 10, LOSS=0.7455153465270996, ROC_AUC=0.8945228257408999
# time for epoch 10: 9.512101173400879 seconds
# on epoch 11
# time for epoch 11: 7.7112884521484375 seconds
# on epoch 12
# epoch: 12, LOSS=0.8286328315734863, ROC_AUC=0.8889372733434309
# time for epoch 12: 9.467072486877441 seconds
# on epoch 13
# time for epoch 13: 7.796626806259155 seconds
# on epoch 14
# epoch: 14, LOSS=0.7486018538475037, ROC_AUC=0.891384260377497
# time for epoch 14: 9.71759819984436 seconds
# on epoch 15
# time for epoch 15: 7.564198732376099 seconds
# on epoch 16
# epoch: 16, LOSS=0.6611166000366211, ROC_AUC=0.9190870307171599
# time for epoch 16: 9.960120439529419 seconds
# on epoch 17
# time for epoch 17: 7.568461894989014 seconds
# on epoch 18
# epoch: 18, LOSS=0.6560055613517761, ROC_AUC=0.8797124849525035
# time for epoch 18: 9.525436162948608 seconds
# on epoch 19
# time for epoch 19: 7.5412278175354 seconds
# on epoch 20
# epoch: 20, LOSS=0.7171987891197205, ROC_AUC=0.9104547046215884
# time for epoch 20: 9.729164123535156 seconds
# on epoch 21
# time for epoch 21: 7.518292188644409 seconds
# on epoch 22
# epoch: 22, LOSS=0.6386791467666626, ROC_AUC=0.9210789443164694
# time for epoch 22: 9.475328922271729 seconds
# on epoch 23
# time for epoch 23: 7.504238605499268 seconds
# on epoch 24
# epoch: 24, LOSS=0.5956897735595703, ROC_AUC=0.934358039630282
# time for epoch 24: 9.442950248718262 seconds
# on epoch 25
# time for epoch 25: 7.592297077178955 seconds
# on epoch 26
# epoch: 26, LOSS=0.6796609163284302, ROC_AUC=0.9362634880843537
# time for epoch 26: 9.462602376937866 seconds
# on epoch 27
# time for epoch 27: 7.785106897354126 seconds
# on epoch 28
# epoch: 28, LOSS=0.6408441066741943, ROC_AUC=0.9108538711893459
# time for epoch 28: 9.450891494750977 seconds
# on epoch 29
# time for epoch 29: 7.777122259140015 seconds
# on epoch 30
# epoch: 30, LOSS=0.5716646313667297, ROC_AUC=0.9092637888130708
# time for epoch 30: 9.726470947265625 seconds
# on epoch 31
# time for epoch 31: 7.795771360397339 seconds
# on epoch 32
# epoch: 32, LOSS=0.5601534247398376, ROC_AUC=0.9353156287516571
# time for epoch 32: 9.496210098266602 seconds
# on epoch 33
# time for epoch 33: 7.842244386672974 seconds
# on epoch 34
# epoch: 34, LOSS=0.5620930194854736, ROC_AUC=0.940792930906863
# time for epoch 34: 9.920130968093872 seconds
# on epoch 35
# time for epoch 35: 7.596755027770996 seconds
# on epoch 36
# epoch: 36, LOSS=0.539436399936676, ROC_AUC=0.9471398314194032
# time for epoch 36: 9.52941346168518 seconds
# on epoch 37
# time for epoch 37: 7.6207897663116455 seconds
# on epoch 38
# epoch: 38, LOSS=0.5144944190979004, ROC_AUC=0.9506030253469042
# time for epoch 38: 9.783994913101196 seconds
# on epoch 39
# time for epoch 39: 7.887350082397461 seconds
# on epoch 40
# epoch: 40, LOSS=0.4767969846725464, ROC_AUC=0.9585179962416518
# time for epoch 40: 9.968204021453857 seconds
# on epoch 41
# time for epoch 41: 7.625483512878418 seconds
# on epoch 42
# epoch: 42, LOSS=0.5201593041419983, ROC_AUC=0.9595440205071105
# time for epoch 42: 10.258388042449951 seconds
# on epoch 43
# time for epoch 43: 7.554295301437378 seconds
# on epoch 44
# epoch: 44, LOSS=0.3983498811721802, ROC_AUC=0.9712856673351301
# time for epoch 44: 9.415799379348755 seconds
# on epoch 45
# time for epoch 45: 7.552221059799194 seconds
# on epoch 46
# epoch: 46, LOSS=0.36657631397247314, ROC_AUC=0.976003250554961
# time for epoch 46: 9.762610912322998 seconds
# on epoch 47
# time for epoch 47: 7.54551100730896 seconds
# on epoch 48
# epoch: 48, LOSS=0.3483571410179138, ROC_AUC=0.977665097610362
# time for epoch 48: 9.690826177597046 seconds
# on epoch 49
# time for epoch 49: 7.558411121368408 seconds
# on epoch 50
# epoch: 50, LOSS=0.276532918214798, ROC_AUC=0.9853941668520317
# time for epoch 50: 9.407848596572876 seconds
# area under curve not changing significantly, exit loop
# on epoch 51
# time for epoch 51: 7.848430395126343 seconds
# area under curve not changing significantly, exit loop
# on epoch 52
# epoch: 52, LOSS=0.2921350300312042, ROC_AUC=0.9855021140724941
# time for epoch 52: 9.894551992416382 seconds
# area under curve not changing significantly, exit loop
# on epoch 53
# time for epoch 53: 7.703121662139893 seconds
# area under curve not changing significantly, exit loop
# on epoch 54
# epoch: 54, LOSS=0.3264673948287964, ROC_AUC=0.98346462555351
# time for epoch 54: 9.49242353439331 seconds
# area under curve not changing significantly, exit loop
# on epoch 55
# time for epoch 55: 7.599416017532349 seconds
# area under curve not changing significantly, exit loop
# on epoch 56
# epoch: 56, LOSS=0.2911645174026489, ROC_AUC=0.9836458443542909
# time for epoch 56: 9.7611083984375 seconds
# area under curve not changing significantly, exit loop
# on epoch 57
# time for epoch 57: 7.672320127487183 seconds
# area under curve not changing significantly, exit loop
# on epoch 58
# epoch: 58, LOSS=0.32077908515930176, ROC_AUC=0.9823327382252571
# time for epoch 58: 9.763920783996582 seconds
# area under curve not changing significantly, exit loop
# on epoch 59
# time for epoch 59: 7.607313632965088 seconds
# area under curve not changing significantly, exit loop
# on epoch 60
# epoch: 60, LOSS=0.2794664800167084, ROC_AUC=0.9866580328332407
# time for epoch 60: 9.772708415985107 seconds
# area under curve not changing significantly, exit loop
# on epoch 61
# time for epoch 61: 7.626955032348633 seconds
# area under curve not changing significantly, exit loop
# on epoch 62
# epoch: 62, LOSS=0.2533658742904663, ROC_AUC=0.9878153221342121
# time for epoch 62: 9.766998529434204 seconds
# area under curve not changing significantly, exit loop
# on epoch 63
# time for epoch 63: 7.6053595542907715 seconds
# area under curve not changing significantly, exit loop
# on epoch 64
# epoch: 64, LOSS=0.2085329294204712, ROC_AUC=0.990094924998583
# time for epoch 64: 9.78926420211792 seconds
# area under curve not changing significantly, exit loop
# on epoch 65
# time for epoch 65: 7.890975475311279 seconds
# area under curve not changing significantly, exit loop
# on epoch 66
# epoch: 66, LOSS=0.25439783930778503, ROC_AUC=0.9864536871496755
# time for epoch 66: 9.51909875869751 seconds
# area under curve not changing significantly, exit loop
# on epoch 67
# time for epoch 67: 7.895965337753296 seconds
# area under curve not changing significantly, exit loop
# on epoch 68
# epoch: 68, LOSS=0.21570329368114471, ROC_AUC=0.9908764491897929
# time for epoch 68: 9.605118989944458 seconds
# area under curve not changing significantly, exit loop
# on epoch 69
# time for epoch 69: 7.5986034870147705 seconds
# area under curve not changing significantly, exit loop
# on epoch 70
# epoch: 70, LOSS=0.24761292338371277, ROC_AUC=0.9904624735727429
# time for epoch 70: 9.493897199630737 seconds
# area under curve not changing significantly, exit loop
# on epoch 71
# time for epoch 71: 7.612200021743774 seconds
# area under curve not changing significantly, exit loop
# on epoch 72
# epoch: 72, LOSS=0.18148255348205566, ROC_AUC=0.9922618245625455
# time for epoch 72: 9.760374069213867 seconds
# area under curve not changing significantly, exit loop
# on epoch 73
# time for epoch 73: 7.880825519561768 seconds
# area under curve not changing significantly, exit loop
# on epoch 74
# epoch: 74, LOSS=0.193376824259758, ROC_AUC=0.9913166819319058
# time for epoch 74: 9.589346647262573 seconds
# area under curve not changing significantly, exit loop
# on epoch 75
# time for epoch 75: 7.588505029678345 seconds
# area under curve not changing significantly, exit loop
# on epoch 76
# epoch: 76, LOSS=0.17484736442565918, ROC_AUC=0.993977944949437
# time for epoch 76: 9.720635652542114 seconds
# area under curve not changing significantly, exit loop
# on epoch 77
# time for epoch 77: 7.863913059234619 seconds
# area under curve not changing significantly, exit loop
# on epoch 78
# epoch: 78, LOSS=0.20847401022911072, ROC_AUC=0.9912656575345317
# time for epoch 78: 9.474060297012329 seconds
# area under curve not changing significantly, exit loop
# on epoch 79
# time for epoch 79: 7.9368736743927 seconds
# area under curve not changing significantly, exit loop
# on epoch 80
# epoch: 80, LOSS=0.23006080090999603, ROC_AUC=0.9904557365562586
# time for epoch 80: 9.475505113601685 seconds
# area under curve not changing significantly, exit loop
# on epoch 81
# time for epoch 81: 7.9147844314575195 seconds
# area under curve not changing significantly, exit loop
# on epoch 82
# epoch: 82, LOSS=0.1844482570886612, ROC_AUC=0.9929059560477453
# time for epoch 82: 9.479319334030151 seconds
# area under curve not changing significantly, exit loop
# on epoch 83
# time for epoch 83: 7.902919054031372 seconds
# area under curve not changing significantly, exit loop
# on epoch 84
# epoch: 84, LOSS=0.18464110791683197, ROC_AUC=0.9933364248983968
# time for epoch 84: 9.466208457946777 seconds
# area under curve not changing significantly, exit loop
# on epoch 85
# time for epoch 85: 7.698651313781738 seconds
# area under curve not changing significantly, exit loop
# on epoch 86
# epoch: 86, LOSS=0.1791333705186844, ROC_AUC=0.9933225730056098
# time for epoch 86: 9.445693969726562 seconds
# area under curve not changing significantly, exit loop
# on epoch 87
# time for epoch 87: 7.595050573348999 seconds
# area under curve not changing significantly, exit loop
# on epoch 88
# epoch: 88, LOSS=0.19382205605506897, ROC_AUC=0.9926216836382217
# time for epoch 88: 9.711201190948486 seconds
# area under curve not changing significantly, exit loop
# on epoch 89
# time for epoch 89: 7.6232099533081055 seconds
# area under curve not changing significantly, exit loop
# on epoch 90
# epoch: 90, LOSS=0.1602555215358734, ROC_AUC=0.9946271719159618
# time for epoch 90: 9.566340684890747 seconds
# area under curve not changing significantly, exit loop
# on epoch 91
# time for epoch 91: 7.566479682922363 seconds
# area under curve not changing significantly, exit loop
# on epoch 92
# epoch: 92, LOSS=0.14642733335494995, ROC_AUC=0.9958220577023349
# time for epoch 92: 9.414376735687256 seconds
# area under curve not changing significantly, exit loop
# on epoch 93
# time for epoch 93: 7.550760984420776 seconds
# area under curve not changing significantly, exit loop
# on epoch 94
# epoch: 94, LOSS=0.15805450081825256, ROC_AUC=0.9959237672421062
# time for epoch 94: 9.376014709472656 seconds
# area under curve not changing significantly, exit loop
# on epoch 95
# time for epoch 95: 7.66310453414917 seconds
# area under curve not changing significantly, exit loop
# on epoch 96
# epoch: 96, LOSS=0.1816166192293167, ROC_AUC=0.9933993638332754
# time for epoch 96: 9.417849779129028 seconds
# area under curve not changing significantly, exit loop
# on epoch 97
# time for epoch 97: 7.841670751571655 seconds
# area under curve not changing significantly, exit loop
# on epoch 98
# epoch: 98, LOSS=0.153032124042511, ROC_AUC=0.9954145608792683
# time for epoch 98: 9.413569927215576 seconds
# area under curve not changing significantly, exit loop
# on epoch 99
# time for epoch 99: 7.815755367279053 seconds
# area under curve not changing significantly, exit loop
# on epoch 100
# epoch: 100, LOSS=0.1385481357574463, ROC_AUC=0.9960273014680864
# time for epoch 100: 9.803089380264282 seconds
# area under curve not changing significantly, exit loop
# total time:  884.9582297801971

# %%
plt.plot(ps_losses)
plt.show()

plt.plot(ps_rocs)
plt.show()

plt.plot(ps_losses_ep)
plt.show()
# Out:
# /home/ubuntu/anaconda3/envs/spatial_torch/lib/python3.5/site-packages/matplotlib/font_manager.py:1328: UserWarning: findfont: Font family ['normal'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
ps_model.eval()
for ind in range(1,20):
    fig, ax = plt.subplots(1,3, figsize=(10,5))
    test_im, test_target = ps_test_ds[ind]
    test_out = ps_model(variable(test_im.unsqueeze(0)))
    ax[0].imshow(test_target.numpy()[0])

    out = test_out.cpu().detach().numpy()[0][0]
    ax[1].imshow(out)

    ax[2].imshow(out>0)
    #ax[2].imshow(test_im.unsqueeze(0).cpu().detach().numpy()[0][0])
    plt.show()
    
    false_positive_rate, true_positive_rate, thresholds = roc_curve(test_target.numpy().flatten(), out.flatten())
    roc_auc = auc(false_positive_rate, true_positive_rate)
    plt.plot(false_positive_rate, true_positive_rate)
    plt.title('AUC: {}'.format(roc_auc))
# Out:
# /home/ubuntu/anaconda3/envs/spatial_torch/lib/python3.5/site-packages/matplotlib/font_manager.py:1328: UserWarning: findfont: Font family ['normal'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %% [markdown]
# ## save the model, AUC, and loss vectors

# %%
save_res = False

if save_res:
    # directory
    save_dir = 'files_PS_bgrn1'
    if not os.path.exists(save_dir):
        os.makedirs(save_dir)

    # save the model
    model_path = 'bgrn1_ps_ep{}_step{}_b{}.pt'.format(num_epochs, step, bsize)
    model_path = os.path.join(save_dir, model_path)
    save = lambda ep: torch.save({
            'model': model.state_dict(),
            'epoch': ep,
            'step': step,
        }, str(model_path))

    save(model_path)

    # save the AUCs
    auc_path = 'auc_bgrn1_ps_ep{}_step{}_b{}.txt'.format(num_epochs, step, bsize)
    auc_path = os.path.join(save_dir, auc_path)
    np.savetxt(auc_path, np.array(rocs))

    #save the loss vectors
    ep_loss_path = 'losses_ep_bgrn1_ps_ep{}_step{}_b{}.txt'.format(num_epochs, step, bsize)
    ep_loss_path = os.path.join(save_dir, ep_loss_path)
    np.savetxt(ep_loss_path, np.array(losses_ep))

    #save the total loss vector
    loss_path = 'loss_bgrn1_ps_ep{}_step{}_b{}.txt'.format(num_epochs, step, bsize)
    loss_path = os.path.join(save_dir, loss_path)
    np.savetxt(loss_path, np.array(losses))
