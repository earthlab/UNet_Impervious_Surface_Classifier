# %%
from glob import glob

# %matplotlib inline
from pylab import *
# import cv2
import rasterio as rio

rcParams['figure.figsize'] = 10, 10

font = {'family' : 'normal',
        'weight' : 'medium',
        'size'   : 14}

matplotlib.rc('font', **font)

import os,sys
from matplotlib import pyplot as plt
import numpy as np
from scipy import misc
import fiona
from shapely.geometry import shape
import shapely
from rasterio.mask import mask
from pyproj import Proj, transform

import rasterio

# add the unet helpers
sys.path.append('../')
from test_unet_helpers import *

# torch stuff
import torch
from torch import nn
from torch.nn import functional as F
import torch
from torchvision import models, datasets
import torchvision
from torchvision.transforms import ToTensor, Normalize, Compose
from utils import variable
# Out:
# /home/ubuntu/anaconda3/envs/spatial_torch/lib/python3.5/site-packages/matplotlib/__init__.py:1067: UserWarning: Duplicate key in file "/home/ubuntu/.config/matplotlib/matplotlibrc", line #2
#   (fname, cnt))
# /home/ubuntu/anaconda3/envs/spatial_torch/lib/python3.5/site-packages/matplotlib/__init__.py:1067: UserWarning: Duplicate key in file "/home/ubuntu/.config/matplotlib/matplotlibrc", line #3
#   (fname, cnt))
# /home/ubuntu/anaconda3/envs/spatial_torch/lib/python3.5/importlib/_bootstrap.py:222: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /home/ubuntu/anaconda3/envs/spatial_torch/lib/python3.5/importlib/_bootstrap.py:222: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /home/ubuntu/anaconda3/envs/spatial_torch/lib/python3.5/importlib/_bootstrap.py:222: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)

# %%
class UNet(nn.Module):
    def __init__(self, in_channels=1, n_classes=2, depth=5, wf=6, padding=False,
                 batch_norm=False, up_mode='upconv'):
        """
        Implementation of
        U-Net: Convolutional Networks for Biomedical Image Segmentation
        (Ronneberger et al., 2015)
        https://arxiv.org/abs/1505.04597
        Using the default arguments will yield the exact version used
        in the original paper
        Args:
            in_channels (int): number of input channels
            n_classes (int): number of output channels
            depth (int): depth of the network
            wf (int): number of filters in the first layer is 2**wf
            padding (bool): if True, apply padding such that the input shape
                            is the same as the output.
                            This may introduce artifacts
            batch_norm (bool): Use BatchNorm after layers with an
                               activation function
            up_mode (str): one of 'upconv' or 'upsample'.
                           'upconv' will use transposed convolutions for
                           learned upsampling.
                           'upsample' will use bilinear upsampling.
        """
        super(UNet, self).__init__()
        assert up_mode in ('upconv', 'upsample')
        self.padding = padding
        self.depth = depth
        prev_channels = in_channels
        self.down_path = nn.ModuleList()
        for i in range(depth):
            self.down_path.append(UNetConvBlock(prev_channels, 2**(wf+i),
                                                padding, batch_norm))
            prev_channels = 2**(wf+i)

        self.up_path = nn.ModuleList()
        for i in reversed(range(depth - 1)):
            self.up_path.append(UNetUpBlock(prev_channels, 2**(wf+i), up_mode,
                                            padding, batch_norm))
            prev_channels = 2**(wf+i)

        self.last = nn.Conv2d(prev_channels, n_classes, kernel_size=1)

    def forward(self, x):
        blocks = []
        for i, down in enumerate(self.down_path):
            x = down(x)
            if i != len(self.down_path)-1:
                blocks.append(x)
                x = F.avg_pool2d(x, 2)

        for i, up in enumerate(self.up_path):
            x = up(x, blocks[-i-1])

        return self.last(x)


class UNetConvBlock(nn.Module):
    def __init__(self, in_size, out_size, padding, batch_norm):
        super(UNetConvBlock, self).__init__()
        block = []

        block.append(nn.Conv2d(in_size, out_size, kernel_size=3,
                               padding=int(padding)))
        block.append(nn.ReLU())
        if batch_norm:
            block.append(nn.BatchNorm2d(out_size))

        block.append(nn.Conv2d(out_size, out_size, kernel_size=3,
                               padding=int(padding)))
        block.append(nn.ReLU())
        if batch_norm:
            block.append(nn.BatchNorm2d(out_size))

        self.block = nn.Sequential(*block)

    def forward(self, x):
        out = self.block(x)
        return out


class UNetUpBlock(nn.Module):
    def __init__(self, in_size, out_size, up_mode, padding, batch_norm):
        super(UNetUpBlock, self).__init__()
        if up_mode == 'upconv':
            self.up = nn.ConvTranspose2d(in_size, out_size, kernel_size=2,
                                         stride=2)
        elif up_mode == 'upsample':
            self.up = nn.Sequential(nn.Upsample(mode='bilinear', scale_factor=2),
                                    nn.Conv2d(in_size, out_size, kernel_size=1))

        self.conv_block = UNetConvBlock(in_size, out_size, padding, batch_norm)

    def center_crop(self, layer, target_size):
        _, _, layer_height, layer_width = layer.size()
        diff_y = (layer_height - target_size[0]) // 2
        diff_x = (layer_width - target_size[1]) // 2
        return layer[:, :, diff_y:(diff_y + target_size[0]), diff_x:(diff_x + target_size[1])]

    def forward(self, x, bridge):
        up = self.up(x)
        crop1 = self.center_crop(bridge, up.shape[2:])
        out = torch.cat([up, crop1], 1)
        out = self.conv_block(out)

        return out

from glob import glob
class DG_GT_Dataset(Dataset):
    """Dataset class for ignition types (Y var)"""
    
    def __init__(self, data_dir, channels='all', img_transform=None, gt_transform=None):
        """ 
        Args:
            data_dir (string): the folder containing the image files
            channels (string): 'all', 'bgr', 'bgrn1', 'bgrn2'; band sets for DG imagery
            img_transform (callable, optional): Optional transform to  be applied to source image data
            gt_transform (callable, optional): Optional transform to  be applied to labeled image data
            x_var (iterable, optional): list of predictor variable names
            land_mask (string, optional): defines whether or not to return land mask
        """
        
        # some sanity checks
        assert os.path.exists(data_dir)
        
        self.gt_files = sorted(glob(data_dir + '/gt*.tif'))
        self.img_files = sorted(glob(data_dir + '/dg*.tif'))
        
        
        print(self.img_files[0])
        print(self.gt_files[0])
        
        self.img_transform = img_transform
        self.gt_transform = gt_transform
        self.dg_bgr = [1,2,4]
        self.dg_bgrn1 = [1,2,4,6]
        self.dg_bgrn2 = [1,2,4,7]
        self.channels = channels
        
        assert len(self.img_files) == len(self.gt_files)
        
    
    def __getitem__(self, idx):
        
        """
            Files are organized as <var_type>_<year>_<month>_t<tileNumber>.tif, e.g., Arson_1992_1_t1
            A single dataset needs to be constructed for a given ignition type, year, month, and tile number
        """
        
        img_file = self.img_files[idx]
        gt_file = self.gt_files[idx]
        
        with rio.open(img_file) as src:
            img_arr = src.read()
            
        # check the channels
        if self.channels == 'bgr':
            img_arr = img_arr[self.dg_bgr, :, :]
        elif self.channels == 'bgrn1':
            img_arr = img_arr[self.dg_bgrn1, :, :]
        elif self.channels == 'bgrn2':
            img_arr = img_arr[self.dg_bgrn2, :, :]
        else:
            pass
            
        with rio.open(gt_file) as src:
            gt_arr = src.read()

        if (self.img_transform is not None):
            return (self.img_transform(torch.from_numpy(img_arr)), 
                    self.gt_transform(torch.from_numpy(gt_arr)))   
        else:
            return (torch.from_numpy(img_arr), torch.from_numpy(gt_arr)) # return X, Y, Mask (Mask uses LandMask in X-var folder)
        
        
    def __len__(self):
        return len(self.img_files)

# %% [markdown]
# # Now that data is ready, set up the model and run through it

# %% [markdown]
# ## some code for saving the model

# %%
from datetime import datetime

def write_event(log, step: int, **data):
    data['step'] = step
    data['dt'] = datetime.now().isoformat()
    log.write(json.dumps(data, sort_keys=True))
    log.write('\n')
    log.flush()
    
save = lambda ep: torch.save({
        'model': model.state_dict(),
        'epoch': ep,
        'step': step,
    }, str(model_path))

# %% [markdown]
# ## some code for setting up the model and performance eval

# %%
import utils as pyt_utils
from torch.optim import Adam
import torch.backends.cudnn as cudnn
from pathlib import Path
from validation import validation_binary
from loss import LossBinary
import json

import time
from sklearn.metrics import roc_auc_score, log_loss, roc_auc_score, roc_curve, auc

# need to change this to DICE loss!
#loss = LossBinary(jaccard_weight=args.jaccard_weight)
#criterion = nn.CrossEntropyLoss()


cudnn.benchmark = True
# Out:
# /home/ubuntu/anaconda3/envs/spatial_torch/lib/python3.5/importlib/_bootstrap.py:222: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /home/ubuntu/anaconda3/envs/spatial_torch/lib/python3.5/importlib/_bootstrap.py:222: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)

# %% [markdown]
# # DO the same for pansharpened data

# %%
train_folder = r'D:\projects\RD\debug_IS_segmentation\tilesPS_d10000_512x512\train'
test_folder = r'D:\projects\RD\debug_IS_segmentation\tilesPS_d10000_512x512\test'
val_folder = r'D:\projects\RD\debug_IS_segmentation\tilesPS_d10000_512x512\val'

# ubuntu paths
train_folder = '/media/joemcglinchy/Data/projects/RD/debug_IS_segmentation/kmeans3_split/tilesPS_d10000_512x512/train'
test_folder = '/media/joemcglinchy/Data/projects/RD/debug_IS_segmentation/kmeans3_split/tilesPS_d10000_512x512/test'
val_folder = '/media/joemcglinchy/Data/projects/RD/debug_IS_segmentation/kmeans3_split/tilesPS_d10000_512x512/val'

# aws pathts
train_folder = '../../tiles/kmeans3_split/tilesPS_d10000_512x512/train'
test_folder = '../../tiles/kmeans3_split/tilesPS_d10000_512x512/test'
val_folder = '../../tiles/kmeans3_split/tilesPS_d10000_512x512/val'

# load as 3 band
ps_train_ds = DG_GT_Dataset(train_folder)
ps_test_ds = DG_GT_Dataset(test_folder)
ps_val_ds = DG_GT_Dataset(val_folder)
# Out:
# ../../tiles/kmeans3_split/tilesPS_d10000_512x512/train/dg_is_00000.tif
# ../../tiles/kmeans3_split/tilesPS_d10000_512x512/train/gt_is_00000.tif
# ../../tiles/kmeans3_split/tilesPS_d10000_512x512/test/dg_is_00731.tif
# ../../tiles/kmeans3_split/tilesPS_d10000_512x512/test/gt_is_00731.tif
# ../../tiles/kmeans3_split/tilesPS_d10000_512x512/val/dg_is_00500.tif
# ../../tiles/kmeans3_split/tilesPS_d10000_512x512/val/gt_is_00500.tif

# %%
# iterate over some batch sizes
times = []
# batch_sizes = [50, 100, 200,300,400,500,600,700,800,900,1000]
# smaller batch sizes as per https://stats.stackexchange.com/questions/164876/tradeoff-batch-size-vs-number-of-iterations-to-train-a-neural-network
#model = unet11_MS(num_bands=4, pretrained=False)

# set some parameters
lr = 0.0001
bsize = 24 # was 32
ps_model = UNet(in_channels=8, n_classes=1, depth=5, wf=6, padding=True, batch_norm=False, up_mode='upconv')
ps_optimizer = Adam(ps_model.parameters(), lr=lr)
ps_criterion = LossBinary(jaccard_weight=1.0)

###### specify DataLoaders
n_workers=4 # for some unknown reason, 0 is enabling all GPUs when 4 had previously done the trick. could be slower.
ps_train_dl = DataLoader(ps_train_ds, batch_size=bsize, shuffle=True, num_workers=n_workers)
ps_test_dl = DataLoader(ps_test_ds, batch_size=bsize, shuffle=True, num_workers=n_workers)


# make model parallel and on GPU
# device=torch.device("cpu")
device = torch.device("cuda" if torch.cuda.is_available() else "cpu") # get device for gpu or cpu
if torch.cuda.device_count() >= 1:
    print("Let's use", torch.cuda.device_count(), "GPUs!")
    ps_model = nn.DataParallel(ps_model)
    ps_model.to(device)
# Out:
# Let's use 4 GPUs!

# %%
device
# Out:
# device(type='cuda')

# %%
print('batchsize, ', bsize)
ps_mean_loss = 0.0
ps_running_loss = 0.0
print('training...')

ps_losses=[]
ps_losses_ep = []
#tl = zip(dg_dl_train, gt_dl_train)
ps_step=0
# record time for one epoch
ps_rocs = []

#####################################################

t0 = time.time()
num_epochs = 100
for epoch in range(num_epochs):
    
#     try:
    te = time.time()

    epoch_i = epoch+1
    print('on epoch {}'.format(epoch_i))

    running_loss = 0
    for i, (inputs_, targets_) in enumerate(ps_train_dl):

        #print('hi')

        # get the inputs
        targets_ = targets_.type(torch.FloatTensor)

        #inputs, targets = variable(inputs_).cuda(), variable(targets_).cuda()
        inputs, targets = variable(inputs_), variable(targets_)
        inputs.to(device)
        targets.to(device)

        outputs = ps_model(inputs)

        # zero parameter gradients
        ps_optimizer.zero_grad()

        # forward + backward + optimize            
        i_loss = ps_criterion(outputs, targets)                
        i_loss.backward()
        ps_optimizer.step()
        ps_step+=1

        running_loss += i_loss
        
        if i%5 == 0: # print/store every 10
            ps_losses.append(i_loss)
            #running_loss += i_loss
            #print('[%d, %5d] loss: %.3f' %(epoch, i + 1, i_loss))

    # get some numbers for the ROC curve
    if epoch_i%2 == 0:
        pred_y = outputs.cpu().data.numpy().squeeze().flatten()
        target_y = targets.cpu().data.numpy().flatten()
        tu = (i_loss, roc_auc_score(target_y,pred_y ))
        print ('epoch: {}, LOSS={}, ROC_AUC={} '.format(epoch_i, *tu))  
        ps_rocs.append(tu[1])


    ps_losses_ep.append(running_loss)
    te1 = time.time()
    print('time for epoch {}: {} seconds'.format(epoch_i, te1-te))

    # early exit critera
    if len(ps_rocs)>2:
        if (np.abs(ps_rocs[-1] - ps_rocs[-2]) < 0.009) and (ps_rocs[-1] > 0.98):
            print('area under curve not changing significantly, exit loop')
            break_flag = False
            
            if break_flag:
                break

#     except Exception as e:
#         print('something happened')
#         print(e)
#         break
        
        
t1 = time.time()
print ('total time: ',t1 - t0)
times.append(t1-t0)
# Out:
# batchsize,  24
# training...
# on epoch 1
# /home/ubuntu/anaconda3/envs/spatial_torch/lib/python3.5/site-packages/torch/nn/functional.py:1006: UserWarning: nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.
#   warnings.warn("nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.")
# time for epoch 1: 43.66544032096863 seconds
# on epoch 2
# epoch: 2, LOSS=1.147007942199707, ROC_AUC=0.6710389467777423
# time for epoch 2: 14.245635747909546 seconds
# on epoch 3
# time for epoch 3: 12.211529731750488 seconds
# on epoch 4
# epoch: 4, LOSS=0.8981292247772217, ROC_AUC=0.8731920191519258
# time for epoch 4: 14.356226205825806 seconds
# on epoch 5
# time for epoch 5: 12.436648845672607 seconds
# on epoch 6
# epoch: 6, LOSS=0.7464061975479126, ROC_AUC=0.8663508040755973
# time for epoch 6: 14.303803443908691 seconds
# on epoch 7
# time for epoch 7: 12.212158918380737 seconds
# on epoch 8
# epoch: 8, LOSS=0.8534878492355347, ROC_AUC=0.8631482522665019
# time for epoch 8: 14.31560206413269 seconds
# on epoch 9
# time for epoch 9: 12.374681949615479 seconds
# on epoch 10
# epoch: 10, LOSS=0.7659010887145996, ROC_AUC=0.8677772765427471
# time for epoch 10: 14.65217924118042 seconds
# on epoch 11
# time for epoch 11: 12.312646389007568 seconds
# on epoch 12
# epoch: 12, LOSS=0.6914929151535034, ROC_AUC=0.8984249560395628
# time for epoch 12: 14.408441066741943 seconds
# on epoch 13
# time for epoch 13: 12.260318279266357 seconds
# on epoch 14
# epoch: 14, LOSS=0.6593390703201294, ROC_AUC=0.9136363355480168
# time for epoch 14: 14.305459260940552 seconds
# on epoch 15
# time for epoch 15: 12.635658979415894 seconds
# on epoch 16
# epoch: 16, LOSS=0.6052535772323608, ROC_AUC=0.8946686257557709
# time for epoch 16: 15.079720973968506 seconds
# on epoch 17
# time for epoch 17: 12.54794192314148 seconds
# on epoch 18
# epoch: 18, LOSS=0.7882061004638672, ROC_AUC=0.9065991443191701
# time for epoch 18: 14.35297966003418 seconds
# on epoch 19
# time for epoch 19: 12.36225938796997 seconds
# on epoch 20
# epoch: 20, LOSS=0.6560178995132446, ROC_AUC=0.9219083558753434
# time for epoch 20: 14.677977085113525 seconds
# on epoch 21
# time for epoch 21: 12.658913373947144 seconds
# on epoch 22
# epoch: 22, LOSS=0.629203200340271, ROC_AUC=0.9221900950199065
# time for epoch 22: 14.604993104934692 seconds
# on epoch 23
# time for epoch 23: 12.43226671218872 seconds
# on epoch 24
# epoch: 24, LOSS=0.5775358080863953, ROC_AUC=0.9360723579814774
# time for epoch 24: 14.470794916152954 seconds
# on epoch 25
# time for epoch 25: 12.457308530807495 seconds
# on epoch 26
# epoch: 26, LOSS=0.5892903804779053, ROC_AUC=0.9464826652284419
# time for epoch 26: 14.47526216506958 seconds
# on epoch 27
# time for epoch 27: 12.600355386734009 seconds
# on epoch 28
# epoch: 28, LOSS=0.39576035737991333, ROC_AUC=0.9615977519432329
# time for epoch 28: 14.367355108261108 seconds
# on epoch 29
# time for epoch 29: 12.407942056655884 seconds
# on epoch 30
# epoch: 30, LOSS=0.45737308263778687, ROC_AUC=0.9595027132750044
# time for epoch 30: 14.834233045578003 seconds
# on epoch 31
# time for epoch 31: 12.489027738571167 seconds
# on epoch 32
# epoch: 32, LOSS=0.42888420820236206, ROC_AUC=0.9695304810843937
# time for epoch 32: 14.78553032875061 seconds
# on epoch 33
# time for epoch 33: 12.355218887329102 seconds
# on epoch 34
# epoch: 34, LOSS=0.3299371600151062, ROC_AUC=0.9719722163469438
# time for epoch 34: 14.50576400756836 seconds
# on epoch 35
# time for epoch 35: 12.323010921478271 seconds
# on epoch 36
# epoch: 36, LOSS=0.41377773880958557, ROC_AUC=0.9703997917250002
# time for epoch 36: 14.39778470993042 seconds
# on epoch 37
# time for epoch 37: 12.352821111679077 seconds
# on epoch 38
# epoch: 38, LOSS=0.30472296476364136, ROC_AUC=0.9819696387952239
# time for epoch 38: 14.509512424468994 seconds
# on epoch 39
# time for epoch 39: 12.32278299331665 seconds
# on epoch 40
# epoch: 40, LOSS=0.26447826623916626, ROC_AUC=0.9839064179124117
# time for epoch 40: 14.333022356033325 seconds
# area under curve not changing significantly, exit loop
# on epoch 41
# time for epoch 41: 12.316594123840332 seconds
# area under curve not changing significantly, exit loop
# on epoch 42
# epoch: 42, LOSS=0.2560010552406311, ROC_AUC=0.9888776989690171
# time for epoch 42: 14.33582091331482 seconds
# area under curve not changing significantly, exit loop
# on epoch 43
# time for epoch 43: 12.344236373901367 seconds
# area under curve not changing significantly, exit loop
# on epoch 44
# epoch: 44, LOSS=0.2785229980945587, ROC_AUC=0.9859061792499813
# time for epoch 44: 14.337330102920532 seconds
# area under curve not changing significantly, exit loop
# on epoch 45
# time for epoch 45: 12.35036587715149 seconds
# area under curve not changing significantly, exit loop
# on epoch 46
# epoch: 46, LOSS=0.262167751789093, ROC_AUC=0.9861434871427763
# time for epoch 46: 14.412446022033691 seconds
# area under curve not changing significantly, exit loop
# on epoch 47
# time for epoch 47: 12.33854055404663 seconds
# area under curve not changing significantly, exit loop
# on epoch 48
# epoch: 48, LOSS=0.2671245336532593, ROC_AUC=0.9853073593477318
# time for epoch 48: 14.555039644241333 seconds
# area under curve not changing significantly, exit loop
# on epoch 49
# time for epoch 49: 12.635334253311157 seconds
# area under curve not changing significantly, exit loop
# on epoch 50
# epoch: 50, LOSS=0.24623724818229675, ROC_AUC=0.988849436818056
# time for epoch 50: 14.602346420288086 seconds
# area under curve not changing significantly, exit loop
# on epoch 51
# time for epoch 51: 12.390094518661499 seconds
# area under curve not changing significantly, exit loop
# on epoch 52
# epoch: 52, LOSS=0.2464081346988678, ROC_AUC=0.9894295825126895
# time for epoch 52: 14.36333966255188 seconds
# area under curve not changing significantly, exit loop
# on epoch 53
# time for epoch 53: 12.345153570175171 seconds
# area under curve not changing significantly, exit loop
# on epoch 54
# epoch: 54, LOSS=0.23708447813987732, ROC_AUC=0.9898122805194918
# time for epoch 54: 14.356008052825928 seconds
# area under curve not changing significantly, exit loop
# on epoch 55
# time for epoch 55: 12.446314573287964 seconds
# area under curve not changing significantly, exit loop
# on epoch 56
# epoch: 56, LOSS=0.20735111832618713, ROC_AUC=0.9922719459527614
# time for epoch 56: 14.419478178024292 seconds
# area under curve not changing significantly, exit loop
# on epoch 57
# time for epoch 57: 12.466013193130493 seconds
# area under curve not changing significantly, exit loop
# on epoch 58
# epoch: 58, LOSS=0.1546960175037384, ROC_AUC=0.995310273002113
# time for epoch 58: 14.38089632987976 seconds
# area under curve not changing significantly, exit loop
# on epoch 59
# time for epoch 59: 12.609302997589111 seconds
# area under curve not changing significantly, exit loop
# on epoch 60
# epoch: 60, LOSS=0.1883375644683838, ROC_AUC=0.9930660831634517
# time for epoch 60: 14.31775164604187 seconds
# area under curve not changing significantly, exit loop
# on epoch 61
# time for epoch 61: 12.60092806816101 seconds
# area under curve not changing significantly, exit loop
# on epoch 62
# epoch: 62, LOSS=0.1922367662191391, ROC_AUC=0.9928317905582632
# time for epoch 62: 14.37615704536438 seconds
# area under curve not changing significantly, exit loop
# on epoch 63
# time for epoch 63: 12.331828117370605 seconds
# area under curve not changing significantly, exit loop
# on epoch 64
# epoch: 64, LOSS=0.16285869479179382, ROC_AUC=0.9945519845128828
# time for epoch 64: 14.622117280960083 seconds
# area under curve not changing significantly, exit loop
# on epoch 65
# time for epoch 65: 12.384668111801147 seconds
# area under curve not changing significantly, exit loop
# on epoch 66
# epoch: 66, LOSS=0.15182140469551086, ROC_AUC=0.9958363451380922
# time for epoch 66: 14.316619157791138 seconds
# area under curve not changing significantly, exit loop
# on epoch 67
# time for epoch 67: 12.726696968078613 seconds
# area under curve not changing significantly, exit loop
# on epoch 68
# epoch: 68, LOSS=0.16959327459335327, ROC_AUC=0.994750187940671
# time for epoch 68: 14.339394330978394 seconds
# area under curve not changing significantly, exit loop
# on epoch 69
# time for epoch 69: 12.659616470336914 seconds
# area under curve not changing significantly, exit loop
# on epoch 70
# epoch: 70, LOSS=0.08635606616735458, ROC_AUC=0.9977986183175789
# time for epoch 70: 14.564490795135498 seconds
# area under curve not changing significantly, exit loop
# on epoch 71
# time for epoch 71: 12.318143606185913 seconds
# area under curve not changing significantly, exit loop
# on epoch 72
# epoch: 72, LOSS=0.12117711454629898, ROC_AUC=0.9972360068862355
# time for epoch 72: 14.587668895721436 seconds
# area under curve not changing significantly, exit loop
# on epoch 73
# time for epoch 73: 12.584132194519043 seconds
# area under curve not changing significantly, exit loop
# on epoch 74
# epoch: 74, LOSS=0.11394035816192627, ROC_AUC=0.9970877295563628
# time for epoch 74: 14.61565351486206 seconds
# area under curve not changing significantly, exit loop
# on epoch 75
# time for epoch 75: 12.331008195877075 seconds
# area under curve not changing significantly, exit loop
# on epoch 76
# epoch: 76, LOSS=0.1136334240436554, ROC_AUC=0.9974560973748546
# time for epoch 76: 14.266506671905518 seconds
# area under curve not changing significantly, exit loop
# on epoch 77
# time for epoch 77: 12.344343423843384 seconds
# area under curve not changing significantly, exit loop
# on epoch 78
# epoch: 78, LOSS=0.13004568219184875, ROC_AUC=0.9972556588700635
# time for epoch 78: 14.651063442230225 seconds
# area under curve not changing significantly, exit loop
# on epoch 79
# time for epoch 79: 12.668102741241455 seconds
# area under curve not changing significantly, exit loop
# on epoch 80
# epoch: 80, LOSS=0.11109080910682678, ROC_AUC=0.997389232547175
# time for epoch 80: 14.438846826553345 seconds
# area under curve not changing significantly, exit loop
# on epoch 81
# time for epoch 81: 12.349196195602417 seconds
# area under curve not changing significantly, exit loop
# on epoch 82
# epoch: 82, LOSS=0.1450650691986084, ROC_AUC=0.9963521349640434
# time for epoch 82: 14.49478030204773 seconds
# area under curve not changing significantly, exit loop
# on epoch 83
# time for epoch 83: 12.652692079544067 seconds
# area under curve not changing significantly, exit loop
# on epoch 84
# epoch: 84, LOSS=0.08836089074611664, ROC_AUC=0.9982105252818881
# time for epoch 84: 14.433799982070923 seconds
# area under curve not changing significantly, exit loop
# on epoch 85
# time for epoch 85: 12.444849014282227 seconds
# area under curve not changing significantly, exit loop
# on epoch 86
# epoch: 86, LOSS=0.10445789992809296, ROC_AUC=0.9975575019193408
# time for epoch 86: 14.645660400390625 seconds
# area under curve not changing significantly, exit loop
# on epoch 87
# time for epoch 87: 12.409489154815674 seconds
# area under curve not changing significantly, exit loop
# on epoch 88
# epoch: 88, LOSS=0.12242059409618378, ROC_AUC=0.9970294933642745
# time for epoch 88: 14.444799900054932 seconds
# area under curve not changing significantly, exit loop
# on epoch 89
# time for epoch 89: 12.659165143966675 seconds
# area under curve not changing significantly, exit loop
# on epoch 90
# epoch: 90, LOSS=0.09479625523090363, ROC_AUC=0.9980915888153002
# time for epoch 90: 14.408629894256592 seconds
# area under curve not changing significantly, exit loop
# on epoch 91
# time for epoch 91: 12.687553405761719 seconds
# area under curve not changing significantly, exit loop
# on epoch 92
# epoch: 92, LOSS=0.10165289789438248, ROC_AUC=0.997979613458261
# time for epoch 92: 14.290094137191772 seconds
# area under curve not changing significantly, exit loop
# on epoch 93
# time for epoch 93: 12.41353154182434 seconds
# area under curve not changing significantly, exit loop
# on epoch 94
# epoch: 94, LOSS=0.11154735088348389, ROC_AUC=0.9975076250451508
# time for epoch 94: 14.357082605361938 seconds
# area under curve not changing significantly, exit loop
# on epoch 95
# time for epoch 95: 12.657302379608154 seconds
# area under curve not changing significantly, exit loop
# on epoch 96
# epoch: 96, LOSS=0.09271380305290222, ROC_AUC=0.998189999023106
# time for epoch 96: 14.646336317062378 seconds
# area under curve not changing significantly, exit loop
# on epoch 97
# time for epoch 97: 12.526951789855957 seconds
# area under curve not changing significantly, exit loop
# on epoch 98
# epoch: 98, LOSS=0.0919119194149971, ROC_AUC=0.9983420704232319
# time for epoch 98: 14.343895673751831 seconds
# area under curve not changing significantly, exit loop
# on epoch 99
# time for epoch 99: 12.420037508010864 seconds
# area under curve not changing significantly, exit loop
# on epoch 100
# epoch: 100, LOSS=0.10872136801481247, ROC_AUC=0.9977010601471341
# time for epoch 100: 14.35203504562378 seconds
# area under curve not changing significantly, exit loop
# total time:  1377.1382870674133

# %%
plt.plot(ps_losses)
plt.show()

plt.plot(ps_rocs)
plt.show()

plt.plot(ps_losses_ep)
plt.show()
# Out:
# /home/ubuntu/anaconda3/envs/spatial_torch/lib/python3.5/site-packages/matplotlib/font_manager.py:1328: UserWarning: findfont: Font family ['normal'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
ps_model.eval()
for ind in range(1,20):
    fig, ax = plt.subplots(1,3, figsize=(10,5))
    test_im, test_target = ps_test_ds[ind]
    test_out = ps_model(variable(test_im.unsqueeze(0)))
    ax[0].imshow(test_target.numpy()[0])

    out = test_out.cpu().detach().numpy()[0][0]
    ax[1].imshow(out)

    ax[2].imshow(out>0)
    #ax[2].imshow(test_im.unsqueeze(0).cpu().detach().numpy()[0][0])
    plt.show()
    
    false_positive_rate, true_positive_rate, thresholds = roc_curve(test_target.numpy().flatten(), out.flatten())
    roc_auc = auc(false_positive_rate, true_positive_rate)
    plt.plot(false_positive_rate, true_positive_rate)
    plt.title('AUC: {}'.format(roc_auc))
# Out:
# /home/ubuntu/anaconda3/envs/spatial_torch/lib/python3.5/site-packages/matplotlib/font_manager.py:1328: UserWarning: findfont: Font family ['normal'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %% [markdown]
# ## save the model, AUC, and loss vectors

# %%
save_res = False

if save_res:
    # directory
    save_dir = 'files_PS_bgrn1'
    if not os.path.exists(save_dir):
        os.makedirs(save_dir)

    # save the model
    model_path = 'bgrn1_ps_ep{}_step{}_b{}.pt'.format(num_epochs, step, bsize)
    model_path = os.path.join(save_dir, model_path)
    save = lambda ep: torch.save({
            'model': model.state_dict(),
            'epoch': ep,
            'step': step,
        }, str(model_path))

    save(model_path)

    # save the AUCs
    auc_path = 'auc_bgrn1_ps_ep{}_step{}_b{}.txt'.format(num_epochs, step, bsize)
    auc_path = os.path.join(save_dir, auc_path)
    np.savetxt(auc_path, np.array(rocs))

    #save the loss vectors
    ep_loss_path = 'losses_ep_bgrn1_ps_ep{}_step{}_b{}.txt'.format(num_epochs, step, bsize)
    ep_loss_path = os.path.join(save_dir, ep_loss_path)
    np.savetxt(ep_loss_path, np.array(losses_ep))

    #save the total loss vector
    loss_path = 'loss_bgrn1_ps_ep{}_step{}_b{}.txt'.format(num_epochs, step, bsize)
    loss_path = os.path.join(save_dir, loss_path)
    np.savetxt(loss_path, np.array(losses))
