# %%
from glob import glob

# %matplotlib inline
from pylab import *
# import cv2
import rasterio as rio

rcParams['figure.figsize'] = 10, 10

font = {'family' : 'normal',
        'weight' : 'medium',
        'size'   : 14}

matplotlib.rc('font', **font)

import os,sys
from matplotlib import pyplot as plt
import numpy as np
from scipy import misc
import fiona
from shapely.geometry import shape
import shapely
from rasterio.mask import mask
from pyproj import Proj, transform

import rasterio

# add the unet helpers
sys.path.append('../')
from test_unet_helpers import *

# torch stuff
import torch
from torch import nn
from torch.nn import functional as F
import torch
from torchvision import models, datasets
import torchvision
from torchvision.transforms import ToTensor, Normalize, Compose
from utils import variable
# Out:
# /home/ubuntu/anaconda3/envs/spatial_torch/lib/python3.5/site-packages/matplotlib/__init__.py:1067: UserWarning: Duplicate key in file "/home/ubuntu/.config/matplotlib/matplotlibrc", line #2
#   (fname, cnt))
# /home/ubuntu/anaconda3/envs/spatial_torch/lib/python3.5/site-packages/matplotlib/__init__.py:1067: UserWarning: Duplicate key in file "/home/ubuntu/.config/matplotlib/matplotlibrc", line #3
#   (fname, cnt))
# /home/ubuntu/anaconda3/envs/spatial_torch/lib/python3.5/importlib/_bootstrap.py:222: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /home/ubuntu/anaconda3/envs/spatial_torch/lib/python3.5/importlib/_bootstrap.py:222: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /home/ubuntu/anaconda3/envs/spatial_torch/lib/python3.5/importlib/_bootstrap.py:222: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)

# %%
class UNet(nn.Module):
    def __init__(self, in_channels=1, n_classes=2, depth=5, wf=6, padding=False,
                 batch_norm=False, up_mode='upconv'):
        """
        Implementation of
        U-Net: Convolutional Networks for Biomedical Image Segmentation
        (Ronneberger et al., 2015)
        https://arxiv.org/abs/1505.04597
        Using the default arguments will yield the exact version used
        in the original paper
        Args:
            in_channels (int): number of input channels
            n_classes (int): number of output channels
            depth (int): depth of the network
            wf (int): number of filters in the first layer is 2**wf
            padding (bool): if True, apply padding such that the input shape
                            is the same as the output.
                            This may introduce artifacts
            batch_norm (bool): Use BatchNorm after layers with an
                               activation function
            up_mode (str): one of 'upconv' or 'upsample'.
                           'upconv' will use transposed convolutions for
                           learned upsampling.
                           'upsample' will use bilinear upsampling.
        """
        super(UNet, self).__init__()
        assert up_mode in ('upconv', 'upsample')
        self.padding = padding
        self.depth = depth
        prev_channels = in_channels
        self.down_path = nn.ModuleList()
        for i in range(depth):
            self.down_path.append(UNetConvBlock(prev_channels, 2**(wf+i),
                                                padding, batch_norm))
            prev_channels = 2**(wf+i)

        self.up_path = nn.ModuleList()
        for i in reversed(range(depth - 1)):
            self.up_path.append(UNetUpBlock(prev_channels, 2**(wf+i), up_mode,
                                            padding, batch_norm))
            prev_channels = 2**(wf+i)

        self.last = nn.Conv2d(prev_channels, n_classes, kernel_size=1)

    def forward(self, x):
        blocks = []
        for i, down in enumerate(self.down_path):
            x = down(x)
            if i != len(self.down_path)-1:
                blocks.append(x)
                x = F.avg_pool2d(x, 2)

        for i, up in enumerate(self.up_path):
            x = up(x, blocks[-i-1])

        return self.last(x)


class UNetConvBlock(nn.Module):
    def __init__(self, in_size, out_size, padding, batch_norm):
        super(UNetConvBlock, self).__init__()
        block = []

        block.append(nn.Conv2d(in_size, out_size, kernel_size=3,
                               padding=int(padding)))
        block.append(nn.ReLU())
        if batch_norm:
            block.append(nn.BatchNorm2d(out_size))

        block.append(nn.Conv2d(out_size, out_size, kernel_size=3,
                               padding=int(padding)))
        block.append(nn.ReLU())
        if batch_norm:
            block.append(nn.BatchNorm2d(out_size))

        self.block = nn.Sequential(*block)

    def forward(self, x):
        out = self.block(x)
        return out


class UNetUpBlock(nn.Module):
    def __init__(self, in_size, out_size, up_mode, padding, batch_norm):
        super(UNetUpBlock, self).__init__()
        if up_mode == 'upconv':
            self.up = nn.ConvTranspose2d(in_size, out_size, kernel_size=2,
                                         stride=2)
        elif up_mode == 'upsample':
            self.up = nn.Sequential(nn.Upsample(mode='bilinear', scale_factor=2),
                                    nn.Conv2d(in_size, out_size, kernel_size=1))

        self.conv_block = UNetConvBlock(in_size, out_size, padding, batch_norm)

    def center_crop(self, layer, target_size):
        _, _, layer_height, layer_width = layer.size()
        diff_y = (layer_height - target_size[0]) // 2
        diff_x = (layer_width - target_size[1]) // 2
        return layer[:, :, diff_y:(diff_y + target_size[0]), diff_x:(diff_x + target_size[1])]

    def forward(self, x, bridge):
        up = self.up(x)
        crop1 = self.center_crop(bridge, up.shape[2:])
        out = torch.cat([up, crop1], 1)
        out = self.conv_block(out)

        return out

from glob import glob
class DG_GT_Dataset(Dataset):
    """Dataset class for ignition types (Y var)"""
    
    def __init__(self, data_dir, channels='all', img_transform=None, gt_transform=None):
        """ 
        Args:
            data_dir (string): the folder containing the image files
            channels (string): 'all', 'bgr', 'bgrn1', 'bgrn2'; band sets for DG imagery
            img_transform (callable, optional): Optional transform to  be applied to source image data
            gt_transform (callable, optional): Optional transform to  be applied to labeled image data
            x_var (iterable, optional): list of predictor variable names
            land_mask (string, optional): defines whether or not to return land mask
        """
        
        # some sanity checks
        assert os.path.exists(data_dir)
        
        self.gt_files = sorted(glob(data_dir + '/gt*.tif'))
        self.img_files = sorted(glob(data_dir + '/dg*.tif'))
        
        
        print(self.img_files[0])
        print(self.gt_files[0])
        
        self.img_transform = img_transform
        self.gt_transform = gt_transform
        self.dg_bgr = [1,2,4]
        self.dg_bgrn1 = [1,2,4,6]
        self.dg_bgrn2 = [1,2,4,7]
        self.channels = channels
        
        assert len(self.img_files) == len(self.gt_files)
        
    
    def __getitem__(self, idx):
        
        """
            Files are organized as <var_type>_<year>_<month>_t<tileNumber>.tif, e.g., Arson_1992_1_t1
            A single dataset needs to be constructed for a given ignition type, year, month, and tile number
        """
        
        img_file = self.img_files[idx]
        gt_file = self.gt_files[idx]
        
        with rio.open(img_file) as src:
            img_arr = src.read()
            
        # check the channels
        if self.channels == 'bgr':
            img_arr = img_arr[self.dg_bgr, :, :]
        elif self.channels == 'bgrn1':
            img_arr = img_arr[self.dg_bgrn1, :, :]
        elif self.channels == 'bgrn2':
            img_arr = img_arr[self.dg_bgrn2, :, :]
        else:
            pass
            
        with rio.open(gt_file) as src:
            gt_arr = src.read()

        if (self.img_transform is not None):
            return (self.img_transform(torch.from_numpy(img_arr)), 
                    self.gt_transform(torch.from_numpy(gt_arr)))   
        else:
            return (torch.from_numpy(img_arr), torch.from_numpy(gt_arr)) # return X, Y, Mask (Mask uses LandMask in X-var folder)
        
        
    def __len__(self):
        return len(self.img_files)

# %% [markdown]
# # Now that data is ready, set up the model and run through it

# %% [markdown]
# ## some code for saving the model

# %%
from datetime import datetime

def write_event(log, step: int, **data):
    data['step'] = step
    data['dt'] = datetime.now().isoformat()
    log.write(json.dumps(data, sort_keys=True))
    log.write('\n')
    log.flush()
    
save = lambda ep: torch.save({
        'model': model.state_dict(),
        'epoch': ep,
        'step': step,
    }, str(model_path))

# %% [markdown]
# ## some code for setting up the model and performance eval

# %%
import utils as pyt_utils
from torch.optim import Adam
import torch.backends.cudnn as cudnn
from pathlib import Path
from validation import validation_binary
from loss import LossBinary
import json

import time
from sklearn.metrics import roc_auc_score, log_loss, roc_auc_score, roc_curve, auc

# need to change this to DICE loss!
#loss = LossBinary(jaccard_weight=args.jaccard_weight)
#criterion = nn.CrossEntropyLoss()


cudnn.benchmark = True
# Out:
# /home/ubuntu/anaconda3/envs/spatial_torch/lib/python3.5/importlib/_bootstrap.py:222: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /home/ubuntu/anaconda3/envs/spatial_torch/lib/python3.5/importlib/_bootstrap.py:222: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)

# %% [markdown]
# # DO the same for pansharpened data

# %%
train_folder = r'D:\projects\RD\debug_IS_segmentation\tilesPS_d10000_512x512\train'
test_folder = r'D:\projects\RD\debug_IS_segmentation\tilesPS_d10000_512x512\test'
val_folder = r'D:\projects\RD\debug_IS_segmentation\tilesPS_d10000_512x512\val'

# ubuntu paths
train_folder = '/media/joemcglinchy/Data/projects/RD/debug_IS_segmentation/kmeans3_split/tilesPS_d10000_512x512/train'
test_folder = '/media/joemcglinchy/Data/projects/RD/debug_IS_segmentation/kmeans3_split/tilesPS_d10000_512x512/test'
val_folder = '/media/joemcglinchy/Data/projects/RD/debug_IS_segmentation/kmeans3_split/tilesPS_d10000_512x512/val'

# aws pathts
train_folder = '../../tiles/kmeans3_split/tilesPS_d10000_512x512/train'
test_folder = '../../tiles/kmeans3_split/tilesPS_d10000_512x512/test'
val_folder = '../../tiles/kmeans3_split/tilesPS_d10000_512x512/val'

# load as 4 band
ps_train_ds = DG_GT_Dataset(train_folder, channels='bgrn2')
ps_test_ds = DG_GT_Dataset(test_folder, channels='bgrn2')
ps_val_ds = DG_GT_Dataset(val_folder, channels='bgrn2')
# Out:
# ../../tiles/kmeans3_split/tilesPS_d10000_512x512/train/dg_is_00000.tif
# ../../tiles/kmeans3_split/tilesPS_d10000_512x512/train/gt_is_00000.tif
# ../../tiles/kmeans3_split/tilesPS_d10000_512x512/test/dg_is_00731.tif
# ../../tiles/kmeans3_split/tilesPS_d10000_512x512/test/gt_is_00731.tif
# ../../tiles/kmeans3_split/tilesPS_d10000_512x512/val/dg_is_00500.tif
# ../../tiles/kmeans3_split/tilesPS_d10000_512x512/val/gt_is_00500.tif

# %%
# iterate over some batch sizes
times = []
# batch_sizes = [50, 100, 200,300,400,500,600,700,800,900,1000]
# smaller batch sizes as per https://stats.stackexchange.com/questions/164876/tradeoff-batch-size-vs-number-of-iterations-to-train-a-neural-network
#model = unet11_MS(num_bands=4, pretrained=False)

# set some parameters
lr = 0.0001
bsize = 24 # was 32
ps_model = UNet(in_channels=4, n_classes=1, depth=5, wf=6, padding=True, batch_norm=False, up_mode='upconv')
ps_optimizer = Adam(ps_model.parameters(), lr=lr)
ps_criterion = LossBinary(jaccard_weight=1.0)

###### specify DataLoaders
n_workers=4 # for some unknown reason, 0 is enabling all GPUs when 4 had previously done the trick. could be slower.
ps_train_dl = DataLoader(ps_train_ds, batch_size=bsize, shuffle=True, num_workers=n_workers)
ps_test_dl = DataLoader(ps_test_ds, batch_size=bsize, shuffle=True, num_workers=n_workers)


# make model parallel and on GPU
# device=torch.device("cpu")
device = torch.device("cuda" if torch.cuda.is_available() else "cpu") # get device for gpu or cpu
if torch.cuda.device_count() >= 1:
    print("Let's use", torch.cuda.device_count(), "GPUs!")
    ps_model = nn.DataParallel(ps_model)
    ps_model.to(device)
# Out:
# Let's use 4 GPUs!

# %%
device
# Out:
# device(type='cuda')

# %%
print('batchsize, ', bsize)
ps_mean_loss = 0.0
ps_running_loss = 0.0
print('training...')

ps_losses=[]
ps_losses_ep = []
#tl = zip(dg_dl_train, gt_dl_train)
ps_step=0
# record time for one epoch
ps_rocs = []

#####################################################

t0 = time.time()
num_epochs = 100
for epoch in range(num_epochs):
    
#     try:
    te = time.time()

    epoch_i = epoch+1
    print('on epoch {}'.format(epoch_i))

    running_loss = 0
    for i, (inputs_, targets_) in enumerate(ps_train_dl):

        #print('hi')

        # get the inputs
        targets_ = targets_.type(torch.FloatTensor)

        #inputs, targets = variable(inputs_).cuda(), variable(targets_).cuda()
        inputs, targets = variable(inputs_), variable(targets_)
        inputs.to(device)
        targets.to(device)

        outputs = ps_model(inputs)

        # zero parameter gradients
        ps_optimizer.zero_grad()

        # forward + backward + optimize            
        i_loss = ps_criterion(outputs, targets)                
        i_loss.backward()
        ps_optimizer.step()
        ps_step+=1

        running_loss += i_loss
        
        if i%5 == 0: # print/store every 10
            ps_losses.append(i_loss)
            #running_loss += i_loss
            #print('[%d, %5d] loss: %.3f' %(epoch, i + 1, i_loss))

    # get some numbers for the ROC curve
    if epoch_i%2 == 0:
        pred_y = outputs.cpu().data.numpy().squeeze().flatten()
        target_y = targets.cpu().data.numpy().flatten()
        tu = (i_loss, roc_auc_score(target_y,pred_y ))
        print ('epoch: {}, LOSS={}, ROC_AUC={} '.format(epoch_i, *tu))  
        ps_rocs.append(tu[1])


    ps_losses_ep.append(running_loss)
    te1 = time.time()
    print('time for epoch {}: {} seconds'.format(epoch_i, te1-te))

    # early exit critera
    if len(ps_rocs)>2:
        if (np.abs(ps_rocs[-1] - ps_rocs[-2]) < 0.009) and (ps_rocs[-1] > 0.98):
            print('area under curve not changing significantly, exit loop')
            break_flag = False
            
            if break_flag:
                break

#     except Exception as e:
#         print('something happened')
#         print(e)
#         break
        
        
t1 = time.time()
print ('total time: ',t1 - t0)
times.append(t1-t0)
# Out:
# batchsize,  24
# training...
# on epoch 1
# /home/ubuntu/anaconda3/envs/spatial_torch/lib/python3.5/site-packages/torch/nn/functional.py:1006: UserWarning: nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.
#   warnings.warn("nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.")
# time for epoch 1: 42.42538905143738 seconds
# on epoch 2
# epoch: 2, LOSS=1.3503539562225342, ROC_AUC=0.7158571868312302
# time for epoch 2: 13.804843425750732 seconds
# on epoch 3
# time for epoch 3: 11.654131412506104 seconds
# on epoch 4
# epoch: 4, LOSS=0.886634111404419, ROC_AUC=0.8580545042262316
# time for epoch 4: 14.09601378440857 seconds
# on epoch 5
# time for epoch 5: 11.75571084022522 seconds
# on epoch 6
# epoch: 6, LOSS=0.8355578184127808, ROC_AUC=0.8662431982093628
# time for epoch 6: 13.803351640701294 seconds
# on epoch 7
# time for epoch 7: 11.74243950843811 seconds
# on epoch 8
# epoch: 8, LOSS=0.8581627607345581, ROC_AUC=0.8595176326906894
# time for epoch 8: 14.286733388900757 seconds
# on epoch 9
# time for epoch 9: 11.797832250595093 seconds
# on epoch 10
# epoch: 10, LOSS=0.7416837215423584, ROC_AUC=0.8973356045776525
# time for epoch 10: 13.906505107879639 seconds
# on epoch 11
# time for epoch 11: 12.000542402267456 seconds
# on epoch 12
# epoch: 12, LOSS=0.8014516830444336, ROC_AUC=0.8530889698449665
# time for epoch 12: 13.793130159378052 seconds
# on epoch 13
# time for epoch 13: 12.02563738822937 seconds
# on epoch 14
# epoch: 14, LOSS=0.694786548614502, ROC_AUC=0.8923046189456871
# time for epoch 14: 13.783160209655762 seconds
# on epoch 15
# time for epoch 15: 11.968106985092163 seconds
# on epoch 16
# epoch: 16, LOSS=0.7542510628700256, ROC_AUC=0.9161081184796496
# time for epoch 16: 13.839934587478638 seconds
# on epoch 17
# time for epoch 17: 11.819765329360962 seconds
# on epoch 18
# epoch: 18, LOSS=0.5315130949020386, ROC_AUC=0.9203728350615692
# time for epoch 18: 14.283860445022583 seconds
# on epoch 19
# time for epoch 19: 11.79888391494751 seconds
# on epoch 20
# epoch: 20, LOSS=0.6620793342590332, ROC_AUC=0.9027792414308639
# time for epoch 20: 13.837143182754517 seconds
# on epoch 21
# time for epoch 21: 12.077084302902222 seconds
# on epoch 22
# epoch: 22, LOSS=0.7343704700469971, ROC_AUC=0.9104098324988386
# time for epoch 22: 14.290655851364136 seconds
# on epoch 23
# time for epoch 23: 11.767959833145142 seconds
# on epoch 24
# epoch: 24, LOSS=0.6086293458938599, ROC_AUC=0.9341602397143016
# time for epoch 24: 13.846695184707642 seconds
# on epoch 25
# time for epoch 25: 11.837600469589233 seconds
# on epoch 26
# epoch: 26, LOSS=0.5906162261962891, ROC_AUC=0.941491184392777
# time for epoch 26: 13.812318086624146 seconds
# on epoch 27
# time for epoch 27: 12.114123821258545 seconds
# on epoch 28
# epoch: 28, LOSS=0.643980860710144, ROC_AUC=0.9346484704576716
# time for epoch 28: 13.84537672996521 seconds
# on epoch 29
# time for epoch 29: 11.76624870300293 seconds
# on epoch 30
# epoch: 30, LOSS=0.4947231709957123, ROC_AUC=0.9444489496343405
# time for epoch 30: 13.928980350494385 seconds
# on epoch 31
# time for epoch 31: 11.867595434188843 seconds
# on epoch 32
# epoch: 32, LOSS=0.5094679594039917, ROC_AUC=0.9579113298219185
# time for epoch 32: 14.070199012756348 seconds
# on epoch 33
# time for epoch 33: 11.797513961791992 seconds
# on epoch 34
# epoch: 34, LOSS=0.4089129567146301, ROC_AUC=0.9625419757628325
# time for epoch 34: 13.802454471588135 seconds
# on epoch 35
# time for epoch 35: 11.77208161354065 seconds
# on epoch 36
# epoch: 36, LOSS=0.3403412699699402, ROC_AUC=0.9763107071694241
# time for epoch 36: 13.867500305175781 seconds
# on epoch 37
# time for epoch 37: 11.804868698120117 seconds
# on epoch 38
# epoch: 38, LOSS=0.34602975845336914, ROC_AUC=0.97780625982325
# time for epoch 38: 13.727258443832397 seconds
# on epoch 39
# time for epoch 39: 11.773470163345337 seconds
# on epoch 40
# epoch: 40, LOSS=0.3098578453063965, ROC_AUC=0.9802597530732738
# time for epoch 40: 13.760366439819336 seconds
# area under curve not changing significantly, exit loop
# on epoch 41
# time for epoch 41: 11.779255390167236 seconds
# area under curve not changing significantly, exit loop
# on epoch 42
# epoch: 42, LOSS=0.2989179491996765, ROC_AUC=0.9829666679362127
# time for epoch 42: 13.722044467926025 seconds
# area under curve not changing significantly, exit loop
# on epoch 43
# time for epoch 43: 11.796828269958496 seconds
# area under curve not changing significantly, exit loop
# on epoch 44
# epoch: 44, LOSS=0.2857004404067993, ROC_AUC=0.9837686604505076
# time for epoch 44: 14.281473159790039 seconds
# area under curve not changing significantly, exit loop
# on epoch 45
# time for epoch 45: 12.015959024429321 seconds
# area under curve not changing significantly, exit loop
# on epoch 46
# epoch: 46, LOSS=0.3353429436683655, ROC_AUC=0.9815163919752004
# time for epoch 46: 13.837012529373169 seconds
# area under curve not changing significantly, exit loop
# on epoch 47
# time for epoch 47: 12.034497499465942 seconds
# area under curve not changing significantly, exit loop
# on epoch 48
# epoch: 48, LOSS=0.2520262897014618, ROC_AUC=0.9874395671841923
# time for epoch 48: 14.049370527267456 seconds
# area under curve not changing significantly, exit loop
# on epoch 49
# time for epoch 49: 11.791344404220581 seconds
# area under curve not changing significantly, exit loop
# on epoch 50
# epoch: 50, LOSS=0.20256096124649048, ROC_AUC=0.9916262320081664
# time for epoch 50: 13.773126602172852 seconds
# area under curve not changing significantly, exit loop
# on epoch 51
# time for epoch 51: 11.766920804977417 seconds
# area under curve not changing significantly, exit loop
# on epoch 52
# epoch: 52, LOSS=0.23335735499858856, ROC_AUC=0.990174442500023
# time for epoch 52: 13.967369079589844 seconds
# area under curve not changing significantly, exit loop
# on epoch 53
# time for epoch 53: 11.850817203521729 seconds
# area under curve not changing significantly, exit loop
# on epoch 54
# epoch: 54, LOSS=0.16611599922180176, ROC_AUC=0.9936611327396353
# time for epoch 54: 14.105536222457886 seconds
# area under curve not changing significantly, exit loop
# on epoch 55
# time for epoch 55: 11.95233964920044 seconds
# area under curve not changing significantly, exit loop
# on epoch 56
# epoch: 56, LOSS=0.20684176683425903, ROC_AUC=0.9916581622785918
# time for epoch 56: 13.91437554359436 seconds
# area under curve not changing significantly, exit loop
# on epoch 57
# time for epoch 57: 11.838153839111328 seconds
# area under curve not changing significantly, exit loop
# on epoch 58
# epoch: 58, LOSS=0.2080509215593338, ROC_AUC=0.9919556809371786
# time for epoch 58: 14.29268503189087 seconds
# area under curve not changing significantly, exit loop
# on epoch 59
# time for epoch 59: 11.778512954711914 seconds
# area under curve not changing significantly, exit loop
# on epoch 60
# epoch: 60, LOSS=0.18597322702407837, ROC_AUC=0.9926319122459312
# time for epoch 60: 14.16040563583374 seconds
# area under curve not changing significantly, exit loop
# on epoch 61
# time for epoch 61: 11.777912378311157 seconds
# area under curve not changing significantly, exit loop
# on epoch 62
# epoch: 62, LOSS=0.22640062868595123, ROC_AUC=0.9913549602233621
# time for epoch 62: 13.72988748550415 seconds
# area under curve not changing significantly, exit loop
# on epoch 63
# time for epoch 63: 11.910125732421875 seconds
# area under curve not changing significantly, exit loop
# on epoch 64
# epoch: 64, LOSS=0.1734180450439453, ROC_AUC=0.9938046821180254
# time for epoch 64: 13.747688055038452 seconds
# area under curve not changing significantly, exit loop
# on epoch 65
# time for epoch 65: 11.780147790908813 seconds
# area under curve not changing significantly, exit loop
# on epoch 66
# epoch: 66, LOSS=0.1234416663646698, ROC_AUC=0.9963748793021577
# time for epoch 66: 13.71243929862976 seconds
# area under curve not changing significantly, exit loop
# on epoch 67
# time for epoch 67: 12.035871505737305 seconds
# area under curve not changing significantly, exit loop
# on epoch 68
# epoch: 68, LOSS=0.17423918843269348, ROC_AUC=0.9941589516786539
# time for epoch 68: 14.009292364120483 seconds
# area under curve not changing significantly, exit loop
# on epoch 69
# time for epoch 69: 11.869361639022827 seconds
# area under curve not changing significantly, exit loop
# on epoch 70
# epoch: 70, LOSS=0.14702072739601135, ROC_AUC=0.9956988153671638
# time for epoch 70: 13.747745752334595 seconds
# area under curve not changing significantly, exit loop
# on epoch 71
# time for epoch 71: 11.751544952392578 seconds
# area under curve not changing significantly, exit loop
# on epoch 72
# epoch: 72, LOSS=0.13251689076423645, ROC_AUC=0.9961211323713672
# time for epoch 72: 13.779200077056885 seconds
# area under curve not changing significantly, exit loop
# on epoch 73
# time for epoch 73: 11.839802026748657 seconds
# area under curve not changing significantly, exit loop
# on epoch 74
# epoch: 74, LOSS=0.15202230215072632, ROC_AUC=0.9962719777902513
# time for epoch 74: 13.891317367553711 seconds
# area under curve not changing significantly, exit loop
# on epoch 75
# time for epoch 75: 11.808187484741211 seconds
# area under curve not changing significantly, exit loop
# on epoch 76
# epoch: 76, LOSS=0.1376393884420395, ROC_AUC=0.9963879190435744
# time for epoch 76: 13.763691425323486 seconds
# area under curve not changing significantly, exit loop
# on epoch 77
# time for epoch 77: 11.825904607772827 seconds
# area under curve not changing significantly, exit loop
# on epoch 78
# epoch: 78, LOSS=0.14301788806915283, ROC_AUC=0.9960829215122753
# time for epoch 78: 14.142798662185669 seconds
# area under curve not changing significantly, exit loop
# on epoch 79
# time for epoch 79: 11.785402536392212 seconds
# area under curve not changing significantly, exit loop
# on epoch 80
# epoch: 80, LOSS=0.12166578322649002, ROC_AUC=0.9969696823076143
# time for epoch 80: 13.810728311538696 seconds
# area under curve not changing significantly, exit loop
# on epoch 81
# time for epoch 81: 11.772211074829102 seconds
# area under curve not changing significantly, exit loop
# on epoch 82
# epoch: 82, LOSS=0.1277623176574707, ROC_AUC=0.9964250331100442
# time for epoch 82: 13.752826452255249 seconds
# area under curve not changing significantly, exit loop
# on epoch 83
# time for epoch 83: 11.819118022918701 seconds
# area under curve not changing significantly, exit loop
# on epoch 84
# epoch: 84, LOSS=0.12377715855836868, ROC_AUC=0.9970211058453374
# time for epoch 84: 13.71980619430542 seconds
# area under curve not changing significantly, exit loop
# on epoch 85
# time for epoch 85: 11.830341815948486 seconds
# area under curve not changing significantly, exit loop
# on epoch 86
# epoch: 86, LOSS=0.1153159886598587, ROC_AUC=0.9974134035061314
# time for epoch 86: 13.842303276062012 seconds
# area under curve not changing significantly, exit loop
# on epoch 87
# time for epoch 87: 11.799756050109863 seconds
# area under curve not changing significantly, exit loop
# on epoch 88
# epoch: 88, LOSS=0.10830195993185043, ROC_AUC=0.9976064951472998
# time for epoch 88: 13.843350172042847 seconds
# area under curve not changing significantly, exit loop
# on epoch 89
# time for epoch 89: 11.765682697296143 seconds
# area under curve not changing significantly, exit loop
# on epoch 90
# epoch: 90, LOSS=0.0855516567826271, ROC_AUC=0.9983473179738954
# time for epoch 90: 13.774747133255005 seconds
# area under curve not changing significantly, exit loop
# on epoch 91
# time for epoch 91: 11.848089218139648 seconds
# area under curve not changing significantly, exit loop
# on epoch 92
# epoch: 92, LOSS=0.11256510019302368, ROC_AUC=0.9976011433113298
# time for epoch 92: 13.798916578292847 seconds
# area under curve not changing significantly, exit loop
# on epoch 93
# time for epoch 93: 11.82465934753418 seconds
# area under curve not changing significantly, exit loop
# on epoch 94
# epoch: 94, LOSS=0.09678274393081665, ROC_AUC=0.9980748561653838
# time for epoch 94: 13.785698413848877 seconds
# area under curve not changing significantly, exit loop
# on epoch 95
# time for epoch 95: 12.063226699829102 seconds
# area under curve not changing significantly, exit loop
# on epoch 96
# epoch: 96, LOSS=0.10344691574573517, ROC_AUC=0.9977413773192813
# time for epoch 96: 14.177367925643921 seconds
# area under curve not changing significantly, exit loop
# on epoch 97
# time for epoch 97: 11.812741756439209 seconds
# area under curve not changing significantly, exit loop
# on epoch 98
# epoch: 98, LOSS=0.08297885954380035, ROC_AUC=0.998429499999715
# time for epoch 98: 13.766676187515259 seconds
# area under curve not changing significantly, exit loop
# on epoch 99
# time for epoch 99: 11.859839916229248 seconds
# area under curve not changing significantly, exit loop
# on epoch 100
# epoch: 100, LOSS=0.0911870002746582, ROC_AUC=0.9980956583256291
# time for epoch 100: 13.745724201202393 seconds
# area under curve not changing significantly, exit loop
# total time:  1318.0291271209717

# %%
plt.plot(ps_losses)
plt.show()

plt.plot(ps_rocs)
plt.show()

plt.plot(ps_losses_ep)
plt.show()
# Out:
# /home/ubuntu/anaconda3/envs/spatial_torch/lib/python3.5/site-packages/matplotlib/font_manager.py:1328: UserWarning: findfont: Font family ['normal'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
ps_model.eval()
for ind in range(1,20):
    fig, ax = plt.subplots(1,3, figsize=(10,5))
    test_im, test_target = ps_test_ds[ind]
    test_out = ps_model(variable(test_im.unsqueeze(0)))
    ax[0].imshow(test_target.numpy()[0])

    out = test_out.cpu().detach().numpy()[0][0]
    ax[1].imshow(out)

    ax[2].imshow(out>0)
    #ax[2].imshow(test_im.unsqueeze(0).cpu().detach().numpy()[0][0])
    plt.show()
    
    false_positive_rate, true_positive_rate, thresholds = roc_curve(test_target.numpy().flatten(), out.flatten())
    roc_auc = auc(false_positive_rate, true_positive_rate)
    plt.plot(false_positive_rate, true_positive_rate)
    plt.title('AUC: {}'.format(roc_auc))
# Out:
# /home/ubuntu/anaconda3/envs/spatial_torch/lib/python3.5/site-packages/matplotlib/font_manager.py:1328: UserWarning: findfont: Font family ['normal'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %% [markdown]
# ## save the model, AUC, and loss vectors

# %%
save_res = False

if save_res:
    # directory
    save_dir = 'files_PS_bgrn1'
    if not os.path.exists(save_dir):
        os.makedirs(save_dir)

    # save the model
    model_path = 'bgrn1_ps_ep{}_step{}_b{}.pt'.format(num_epochs, step, bsize)
    model_path = os.path.join(save_dir, model_path)
    save = lambda ep: torch.save({
            'model': model.state_dict(),
            'epoch': ep,
            'step': step,
        }, str(model_path))

    save(model_path)

    # save the AUCs
    auc_path = 'auc_bgrn1_ps_ep{}_step{}_b{}.txt'.format(num_epochs, step, bsize)
    auc_path = os.path.join(save_dir, auc_path)
    np.savetxt(auc_path, np.array(rocs))

    #save the loss vectors
    ep_loss_path = 'losses_ep_bgrn1_ps_ep{}_step{}_b{}.txt'.format(num_epochs, step, bsize)
    ep_loss_path = os.path.join(save_dir, ep_loss_path)
    np.savetxt(ep_loss_path, np.array(losses_ep))

    #save the total loss vector
    loss_path = 'loss_bgrn1_ps_ep{}_step{}_b{}.txt'.format(num_epochs, step, bsize)
    loss_path = os.path.join(save_dir, loss_path)
    np.savetxt(loss_path, np.array(losses))
